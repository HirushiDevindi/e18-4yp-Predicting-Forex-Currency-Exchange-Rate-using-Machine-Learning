# %% [markdown]
# <a href="https://colab.research.google.com/github/cepdnaclk/e18-4yp-Predicting-Forex-Currency-Exchange-Rate-using-Machine-Learning/blob/main/models/EURUSD/EURUSD_IN1_LSTM_GRID_Version1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_ta
# Out:
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 3.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas_ta) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.16.0)
# Building wheels for collected packages: pandas_ta
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218907 sha256=7b8751fed2c14b09c153b878554bd8e3d3b7e0b9c585f54fcc875beddf3bcbfd
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas_ta
# Installing collected packages: pandas_ta
# Successfully installed pandas_ta-0.3.14b0

# %%
import pandas as pd
import pandas_ta as ta

data = pd.read_csv('EURUSD=X.csv')

data
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume
# 0     2019-07-05  1.128605  1.128796  1.120825  1.128579   1.128579       0
# 1     2019-07-08  1.122788  1.123722  1.120838  1.122738   1.122738       0
# 2     2019-07-09  1.121479  1.122208  1.119532  1.121604   1.121604       0
# 3     2019-07-10  1.120461  1.126300  1.120260  1.120825   1.120825       0
# 4     2019-07-11  1.126126  1.128796  1.125176  1.125885   1.125885       0
# ...          ...       ...       ...       ...       ...        ...     ...
# 1301  2024-07-01  1.073526  1.077819  1.072076  1.073526   1.073526       0
# 1302  2024-07-02  1.073710  1.074610  1.071065  1.073710   1.073710       0
# 1303  2024-07-03  1.074841  1.081560  1.073710  1.074841   1.074841       0
# 1304  2024-07-04  1.079331  1.081666  1.078423  1.079331   1.079331       0
# 1305  2024-07-05  1.081432  1.084363  1.081198  1.083306   1.083306       0
#
# [1306 rows x 7 columns]

# %%
data['T-4'] = data['Close']
data['T-3'] = data['Close'].shift(-1)
data['T-2'] = data['Close'].shift(-2)
data['T-1'] = data['Close'].shift(-3)
data['T0'] = data['Close'].shift(-4)

data['SMA_5_H'] = ta.sma(data['High'], length=5).shift(-4)
data['SMA_5_L'] = ta.sma(data['Low'], length=5).shift(-4)
data['EMA_5_C'] = ta.ema(data['Close'], length=5).shift(-4)
data['RSI'] = ta.rsi(data['Close'], length=14).shift(-14)

#Closing value of the next day
data['T_F'] = data['Close'].shift(-5)

print(data.head(10))
# Out:
#          Date      Open      High       Low     Close  Adj Close  Volume  \
# 0  2019-07-05  1.128605  1.128796  1.120825  1.128579   1.128579       0
# 1  2019-07-08  1.122788  1.123722  1.120838  1.122738   1.122738       0
# 2  2019-07-09  1.121479  1.122208  1.119532  1.121604   1.121604       0
# 3  2019-07-10  1.120461  1.126300  1.120260  1.120825   1.120825       0
# 4  2019-07-11  1.126126  1.128796  1.125176  1.125885   1.125885       0
# 5  2019-07-12  1.125024  1.127800  1.123974  1.125239   1.125239       0
# 6  2019-07-15  1.127180  1.128599  1.125568  1.127205   1.127205       0
# 7  2019-07-16  1.126088  1.126634  1.120900  1.126177   1.126177       0
# 8  2019-07-17  1.121328  1.123343  1.120109  1.121227   1.121227       0
# 9  2019-07-18  1.122776  1.124733  1.120624  1.122965   1.122965       0
#
#         T-4       T-3       T-2       T-1        T0   SMA_5_H   SMA_5_L  \
# 0  1.128579  1.122738  1.121604  1.120825  1.125885  1.125964  1.121326
# 1  1.122738  1.121604  1.120825  1.125885  1.125239  1.125765  1.121956
# 2  1.121604  1.120825  1.125885  1.125239  1.127205  1.126741  1.122902
# 3  1.120825  1.125885  1.125239  1.127205  1.126177  1.127626  1.123176
# 1291  2024-06-17  1.070217  1.074068  1.074229  1.075153  1.070641  1.074275
#
#        SMA_5_L   EMA_5_C        RSI       T_F
# 0     1.121326  1.123926  28.600071  1.125239
# 1     1.121956  1.124364  29.742124  1.127205
# 2     1.122902  1.125311  27.933541  1.126177
# 3     1.123176  1.125600  31.427960  1.121227
# 4     1.123145  1.124142  35.998432  1.122965
# ...        ...       ...        ...       ...
# 1287  1.071315  1.075348  47.172292  1.074068
# 1288  1.071115  1.074921  47.410069  1.074229
# 1289  1.070940  1.074691  48.931625  1.075153
# 1290  1.070015  1.074845  54.553191  1.070641
# 1291  1.070090  1.073443  58.869789  1.068776
#
# [1292 rows x 11 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(data.index, data['T_F'])

# %%
dates=data['Date'].to_numpy()
middle_matrix =data[['T-4','T-3','T-2','T-1','T0','SMA_5_H','SMA_5_L','EMA_5_C','RSI']].to_numpy()
X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))
Y=data['T_F']

print(dates.shape)
print(X.shape)
print(Y.shape)
# Out:
# (1292,)
# (1292, 9, 1)
# (1292,)

# %%
q_80 = int(len(dates) * .8) #change to 0.8
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], Y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], Y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], Y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras import layers

# # model = Sequential([layers.Input((9, 1)),
# #                     layers.LSTM(300),
# #                     layers.Dense(1)])

# model = Sequential([layers.Input((9, 1)),
#                    layers.LSTM(64),
#                    layers.Dense(10, activation='relu'),
#                    layers.Dense(10, activation='relu'),
#                    layers.Dense(1)])

# model.compile(loss='mse',
#               optimizer=Adam(learning_rate=0.01),
#               metrics=['mean_absolute_error'])

# model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)

import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# Define different parameter values to iterate over
epochs_values = [80, 100]
lstm_units_values = [10, 20, 50]
learning_rate_values = [0.01, 0.001, 0.0001]
dense1_values = [100,150,200]
dense2_values = [40, 60, 80]

best_loss = float('inf')
best_epochs = None
best_lstm_units = None
best_learning_rate = None
best_dense2 = None
best_dense1 = None
hist = []

# Define X_train, y_train, X_val, y_val

# Loop over different parameter combinations
for epochs in epochs_values:
    for lstm_units in lstm_units_values:
        for learning_rate in learning_rate_values:
          for dense1 in dense1_values:
            for dense2 in dense2_values:
                print(f"Training model with epochs={epochs}, lstm_units={lstm_units}, learning_rate={learning_rate}, dense1={dense1}, dense2={dense2}")

                # model = Sequential([layers.Input((9, 1)),
                #         layers.LSTM(lstm_units),
                #         layers.Dense(1)])

                # Define the model
                model = Sequential([
                    layers.Input((9, 1)),
                    layers.LSTM(lstm_units),
                    layers.Dense(dense1, activation='relu'),
                    layers.Dense(dense2, activation='relu'),
                    layers.Dense(1)
                ])

                model.compile(loss='mse',
                              optimizer=Adam(learning_rate=learning_rate),
                              metrics=['mean_absolute_error'])

                # Train the model
                history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epochs, verbose=0)

                # Check if this combination has the best validation loss so far
                if history.history['loss'][-1] < best_loss:
                    hist = history.history
                    best_loss = history.history['loss'][-1]
                    best_epochs = epochs
                    best_lstm_units = lstm_units
                    best_learning_rate = learning_rate
                    best_dense1 = dense1
                    best_dense2 = dense2

# Print the best combination
print(f"Best combination: epochs={best_epochs}, lstm_units={best_lstm_units}, learning_rate={best_learning_rate}, Validation Loss={best_loss}, best_dense1={best_dense1}, best_dense2={best_dense2}")
# Out:
# Training model with epochs=80, lstm_units=10, learning_rate=0.01, dense1=100, dense2=40
# Training model with epochs=80, lstm_units=10, learning_rate=0.01, dense1=100, dense2=60
# Training model with epochs=80, lstm_units=10, learning_rate=0.01, dense1=100, dense2=80
# Training model with epochs=80, lstm_units=10, learning_rate=0.01, dense1=150, dense2=40
# Training model with epochs=80, lstm_units=10, learning_rate=0.01, dense1=150, dense2=60
# Training model with epochs=80, lstm_units=10, learning_rate=0.01, dense1=150, dense2=80
# Training model with epochs=80, lstm_units=10, learning_rate=0.01, dense1=200, dense2=40
# Training model with epochs=80, lstm_units=10, learning_rate=0.01, dense1=200, dense2=60
# Training model with epochs=80, lstm_units=10, learning_rate=0.01, dense1=200, dense2=80
# Training model with epochs=80, lstm_units=10, learning_rate=0.001, dense1=100, dense2=40
# Training model with epochs=80, lstm_units=10, learning_rate=0.001, dense1=100, dense2=60
# Training model with epochs=80, lstm_units=10, learning_rate=0.001, dense1=100, dense2=80
# Training model with epochs=80, lstm_units=10, learning_rate=0.001, dense1=150, dense2=40
# Training model with epochs=80, lstm_units=10, learning_rate=0.001, dense1=150, dense2=60
# Training model with epochs=80, lstm_units=10, learning_rate=0.001, dense1=150, dense2=80
# Training model with epochs=80, lstm_units=10, learning_rate=0.001, dense1=200, dense2=40
# Training model with epochs=80, lstm_units=10, learning_rate=0.001, dense1=200, dense2=60
# Training model with epochs=80, lstm_units=10, learning_rate=0.001, dense1=200, dense2=80
# Training model with epochs=80, lstm_units=10, learning_rate=0.0001, dense1=100, dense2=40
# Training model with epochs=80, lstm_units=10, learning_rate=0.0001, dense1=100, dense2=60
# Training model with epochs=80, lstm_units=10, learning_rate=0.0001, dense1=100, dense2=80
# Training model with epochs=80, lstm_units=10, learning_rate=0.0001, dense1=150, dense2=40
# Training model with epochs=80, lstm_units=10, learning_rate=0.0001, dense1=150, dense2=60
# Training model with epochs=80, lstm_units=10, learning_rate=0.0001, dense1=150, dense2=80
# Training model with epochs=80, lstm_units=10, learning_rate=0.0001, dense1=200, dense2=40
# Training model with epochs=80, lstm_units=10, learning_rate=0.0001, dense1=200, dense2=60
# Training model with epochs=80, lstm_units=10, learning_rate=0.0001, dense1=200, dense2=80
# Training model with epochs=80, lstm_units=20, learning_rate=0.01, dense1=100, dense2=40
# Training model with epochs=80, lstm_units=20, learning_rate=0.01, dense1=100, dense2=60
# Training model with epochs=80, lstm_units=20, learning_rate=0.01, dense1=100, dense2=80
# Training model with epochs=80, lstm_units=20, learning_rate=0.01, dense1=150, dense2=40
# Training model with epochs=80, lstm_units=20, learning_rate=0.01, dense1=150, dense2=60
# Training model with epochs=80, lstm_units=20, learning_rate=0.01, dense1=150, dense2=80
# Training model with epochs=80, lstm_units=20, learning_rate=0.01, dense1=200, dense2=40
# Training model with epochs=80, lstm_units=20, learning_rate=0.01, dense1=200, dense2=60
# Training model with epochs=80, lstm_units=20, learning_rate=0.01, dense1=200, dense2=80
# Training model with epochs=80, lstm_units=20, learning_rate=0.001, dense1=100, dense2=40
# Training model with epochs=80, lstm_units=20, learning_rate=0.001, dense1=100, dense2=60
# Training model with epochs=80, lstm_units=20, learning_rate=0.001, dense1=100, dense2=80
# Training model with epochs=80, lstm_units=20, learning_rate=0.001, dense1=150, dense2=40
# Training model with epochs=80, lstm_units=20, learning_rate=0.001, dense1=150, dense2=60
# Training model with epochs=80, lstm_units=20, learning_rate=0.001, dense1=150, dense2=80
# Training model with epochs=80, lstm_units=20, learning_rate=0.001, dense1=200, dense2=40
# Training model with epochs=80, lstm_units=20, learning_rate=0.001, dense1=200, dense2=60
# Training model with epochs=80, lstm_units=20, learning_rate=0.001, dense1=200, dense2=80
# Training model with epochs=80, lstm_units=20, learning_rate=0.0001, dense1=100, dense2=40
# Training model with epochs=80, lstm_units=20, learning_rate=0.0001, dense1=100, dense2=60
# Training model with epochs=80, lstm_units=20, learning_rate=0.0001, dense1=100, dense2=80
# Training model with epochs=80, lstm_units=20, learning_rate=0.0001, dense1=150, dense2=40
# Training model with epochs=80, lstm_units=20, learning_rate=0.0001, dense1=150, dense2=60
# Training model with epochs=80, lstm_units=20, learning_rate=0.0001, dense1=150, dense2=80
# Training model with epochs=80, lstm_units=20, learning_rate=0.0001, dense1=200, dense2=40
# Training model with epochs=80, lstm_units=20, learning_rate=0.0001, dense1=200, dense2=60
# Training model with epochs=80, lstm_units=20, learning_rate=0.0001, dense1=200, dense2=80
# Training model with epochs=80, lstm_units=50, learning_rate=0.01, dense1=100, dense2=40
# Training model with epochs=80, lstm_units=50, learning_rate=0.01, dense1=100, dense2=60
# Training model with epochs=80, lstm_units=50, learning_rate=0.01, dense1=100, dense2=80
# Training model with epochs=80, lstm_units=50, learning_rate=0.01, dense1=150, dense2=40
# Training model with epochs=80, lstm_units=50, learning_rate=0.01, dense1=150, dense2=60
# Training model with epochs=80, lstm_units=50, learning_rate=0.01, dense1=150, dense2=80
# Training model with epochs=80, lstm_units=50, learning_rate=0.01, dense1=200, dense2=40
# Training model with epochs=80, lstm_units=50, learning_rate=0.01, dense1=200, dense2=60
# Training model with epochs=80, lstm_units=50, learning_rate=0.01, dense1=200, dense2=80
# Training model with epochs=80, lstm_units=50, learning_rate=0.001, dense1=100, dense2=40
# Training model with epochs=80, lstm_units=50, learning_rate=0.001, dense1=100, dense2=60
# Training model with epochs=80, lstm_units=50, learning_rate=0.001, dense1=100, dense2=80
# Training model with epochs=80, lstm_units=50, learning_rate=0.001, dense1=150, dense2=40
# Training model with epochs=80, lstm_units=50, learning_rate=0.001, dense1=150, dense2=60
# Training model with epochs=80, lstm_units=50, learning_rate=0.001, dense1=150, dense2=80
# Training model with epochs=80, lstm_units=50, learning_rate=0.001, dense1=200, dense2=40
# Training model with epochs=80, lstm_units=50, learning_rate=0.001, dense1=200, dense2=60
# Training model with epochs=80, lstm_units=50, learning_rate=0.001, dense1=200, dense2=80
# Training model with epochs=80, lstm_units=50, learning_rate=0.0001, dense1=100, dense2=40
# Training model with epochs=80, lstm_units=50, learning_rate=0.0001, dense1=100, dense2=60
# Training model with epochs=80, lstm_units=50, learning_rate=0.0001, dense1=100, dense2=80
# Training model with epochs=80, lstm_units=50, learning_rate=0.0001, dense1=150, dense2=40
# Training model with epochs=80, lstm_units=50, learning_rate=0.0001, dense1=150, dense2=60
# Training model with epochs=80, lstm_units=50, learning_rate=0.0001, dense1=150, dense2=80
# Training model with epochs=80, lstm_units=50, learning_rate=0.0001, dense1=200, dense2=40
# Training model with epochs=80, lstm_units=50, learning_rate=0.0001, dense1=200, dense2=60
# Training model with epochs=80, lstm_units=50, learning_rate=0.0001, dense1=200, dense2=80
# Training model with epochs=100, lstm_units=10, learning_rate=0.01, dense1=100, dense2=40
# Training model with epochs=100, lstm_units=10, learning_rate=0.01, dense1=100, dense2=60
# Training model with epochs=100, lstm_units=10, learning_rate=0.01, dense1=100, dense2=80
# Training model with epochs=100, lstm_units=10, learning_rate=0.01, dense1=150, dense2=40
# Training model with epochs=100, lstm_units=10, learning_rate=0.01, dense1=150, dense2=60
# Training model with epochs=100, lstm_units=10, learning_rate=0.01, dense1=150, dense2=80
# Training model with epochs=100, lstm_units=10, learning_rate=0.01, dense1=200, dense2=40
# Training model with epochs=100, lstm_units=10, learning_rate=0.01, dense1=200, dense2=60
# Training model with epochs=100, lstm_units=10, learning_rate=0.01, dense1=200, dense2=80
# Training model with epochs=100, lstm_units=10, learning_rate=0.001, dense1=100, dense2=40
# Training model with epochs=100, lstm_units=10, learning_rate=0.001, dense1=100, dense2=60
# Training model with epochs=100, lstm_units=10, learning_rate=0.001, dense1=100, dense2=80
# Training model with epochs=100, lstm_units=10, learning_rate=0.001, dense1=150, dense2=40
# Training model with epochs=100, lstm_units=10, learning_rate=0.001, dense1=150, dense2=60
# Training model with epochs=100, lstm_units=10, learning_rate=0.001, dense1=150, dense2=80
# Training model with epochs=100, lstm_units=10, learning_rate=0.001, dense1=200, dense2=40
# Training model with epochs=100, lstm_units=10, learning_rate=0.001, dense1=200, dense2=60
# Training model with epochs=100, lstm_units=10, learning_rate=0.001, dense1=200, dense2=80
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001, dense1=100, dense2=40
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001, dense1=100, dense2=60
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001, dense1=100, dense2=80
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001, dense1=150, dense2=40
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001, dense1=150, dense2=60
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001, dense1=150, dense2=80
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001, dense1=200, dense2=40
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001, dense1=200, dense2=60
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001, dense1=200, dense2=80
# Training model with epochs=100, lstm_units=20, learning_rate=0.01, dense1=100, dense2=40
# Training model with epochs=100, lstm_units=20, learning_rate=0.01, dense1=100, dense2=60
# Training model with epochs=100, lstm_units=20, learning_rate=0.01, dense1=100, dense2=80
# Training model with epochs=100, lstm_units=20, learning_rate=0.01, dense1=150, dense2=40
# Training model with epochs=100, lstm_units=20, learning_rate=0.01, dense1=150, dense2=60
# Training model with epochs=100, lstm_units=20, learning_rate=0.01, dense1=150, dense2=80
# Training model with epochs=100, lstm_units=20, learning_rate=0.01, dense1=200, dense2=40
# Training model with epochs=100, lstm_units=20, learning_rate=0.01, dense1=200, dense2=60
# Training model with epochs=100, lstm_units=20, learning_rate=0.01, dense1=200, dense2=80
# Training model with epochs=100, lstm_units=20, learning_rate=0.001, dense1=100, dense2=40
# Training model with epochs=100, lstm_units=20, learning_rate=0.001, dense1=100, dense2=60
# Training model with epochs=100, lstm_units=20, learning_rate=0.001, dense1=100, dense2=80
# Training model with epochs=100, lstm_units=20, learning_rate=0.001, dense1=150, dense2=40
# Training model with epochs=100, lstm_units=20, learning_rate=0.001, dense1=150, dense2=60
# Training model with epochs=100, lstm_units=20, learning_rate=0.001, dense1=150, dense2=80
# Training model with epochs=100, lstm_units=20, learning_rate=0.001, dense1=200, dense2=40
# Training model with epochs=100, lstm_units=20, learning_rate=0.001, dense1=200, dense2=60
# Training model with epochs=100, lstm_units=20, learning_rate=0.001, dense1=200, dense2=80
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001, dense1=100, dense2=40
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001, dense1=100, dense2=60
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001, dense1=100, dense2=80
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001, dense1=150, dense2=40
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001, dense1=150, dense2=60
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001, dense1=150, dense2=80
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001, dense1=200, dense2=40
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001, dense1=200, dense2=60
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001, dense1=200, dense2=80
# Training model with epochs=100, lstm_units=50, learning_rate=0.01, dense1=100, dense2=40
# Training model with epochs=100, lstm_units=50, learning_rate=0.01, dense1=100, dense2=60
# Training model with epochs=100, lstm_units=50, learning_rate=0.01, dense1=100, dense2=80
# Training model with epochs=100, lstm_units=50, learning_rate=0.01, dense1=150, dense2=40
# Training model with epochs=100, lstm_units=50, learning_rate=0.01, dense1=150, dense2=60
# Training model with epochs=100, lstm_units=50, learning_rate=0.01, dense1=150, dense2=80
# Training model with epochs=100, lstm_units=50, learning_rate=0.01, dense1=200, dense2=40
# Training model with epochs=100, lstm_units=50, learning_rate=0.01, dense1=200, dense2=60
# Training model with epochs=100, lstm_units=50, learning_rate=0.01, dense1=200, dense2=80
# Training model with epochs=100, lstm_units=50, learning_rate=0.001, dense1=100, dense2=40
# Training model with epochs=100, lstm_units=50, learning_rate=0.001, dense1=100, dense2=60
# Training model with epochs=100, lstm_units=50, learning_rate=0.001, dense1=100, dense2=80
# Training model with epochs=100, lstm_units=50, learning_rate=0.001, dense1=150, dense2=40
# Training model with epochs=100, lstm_units=50, learning_rate=0.001, dense1=150, dense2=60
# Training model with epochs=100, lstm_units=50, learning_rate=0.001, dense1=150, dense2=80
# Training model with epochs=100, lstm_units=50, learning_rate=0.001, dense1=200, dense2=40
# Training model with epochs=100, lstm_units=50, learning_rate=0.001, dense1=200, dense2=60
# Training model with epochs=100, lstm_units=50, learning_rate=0.001, dense1=200, dense2=80
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001, dense1=100, dense2=40
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001, dense1=100, dense2=60
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001, dense1=100, dense2=80
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001, dense1=150, dense2=40
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001, dense1=150, dense2=60
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001, dense1=150, dense2=80
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001, dense1=200, dense2=40
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001, dense1=200, dense2=60
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001, dense1=200, dense2=80
# Best combination: epochs=100, lstm_units=10, learning_rate=0.001, Validation Loss=4.9338686949340627e-05, best_dense1=150, best_dense2=60

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# model = Sequential([layers.Input((9, 1)),
#                     layers.LSTM(64),
#                     layers.Dense(1)])

model = Sequential([layers.Input((9, 1)),
                   layers.LSTM(10),
                   layers.Dense(150, activation='relu'),
                   layers.Dense(60, activation='relu'),
                   layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])


history=model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=100)

print(history.history.keys())

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

# Add labels and legend
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/100
# 33/33 [==============================] - 3s 20ms/step - loss: 0.3965 - mean_absolute_error: 0.5118 - val_loss: 0.0425 - val_mean_absolute_error: 0.2056
# Epoch 2/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0117 - mean_absolute_error: 0.0869 - val_loss: 0.0012 - val_mean_absolute_error: 0.0304
# Epoch 3/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0033 - mean_absolute_error: 0.0472 - val_loss: 0.0011 - val_mean_absolute_error: 0.0293
# Epoch 4/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0454 - val_loss: 0.0016 - val_mean_absolute_error: 0.0360
# Epoch 5/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0031 - mean_absolute_error: 0.0454 - val_loss: 0.0014 - val_mean_absolute_error: 0.0336
# Epoch 6/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0030 - mean_absolute_error: 0.0451 - val_loss: 0.0016 - val_mean_absolute_error: 0.0363
# Epoch 7/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0450 - val_loss: 9.5838e-04 - val_mean_absolute_error: 0.0270
# Epoch 8/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0445 - val_loss: 8.7209e-04 - val_mean_absolute_error: 0.0255
# Epoch 9/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0030 - mean_absolute_error: 0.0445 - val_loss: 0.0016 - val_mean_absolute_error: 0.0363
# Epoch 10/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0443 - val_loss: 0.0013 - val_mean_absolute_error: 0.0328
# Epoch 11/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0029 - mean_absolute_error: 0.0439 - val_loss: 6.1496e-04 - val_mean_absolute_error: 0.0205
# Epoch 12/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0438 - val_loss: 0.0016 - val_mean_absolute_error: 0.0366
# Epoch 13/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0029 - mean_absolute_error: 0.0436 - val_loss: 0.0022 - val_mean_absolute_error: 0.0439
# Epoch 14/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0433 - val_loss: 0.0012 - val_mean_absolute_error: 0.0314
# Epoch 15/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0028 - mean_absolute_error: 0.0431 - val_loss: 0.0018 - val_mean_absolute_error: 0.0390
# Epoch 16/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0027 - mean_absolute_error: 0.0424 - val_loss: 0.0021 - val_mean_absolute_error: 0.0430
# Epoch 17/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0027 - mean_absolute_error: 0.0421 - val_loss: 0.0014 - val_mean_absolute_error: 0.0334
# Epoch 18/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0416 - val_loss: 9.7568e-04 - val_mean_absolute_error: 0.0277
# Epoch 19/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0026 - mean_absolute_error: 0.0415 - val_loss: 0.0011 - val_mean_absolute_error: 0.0290
# Epoch 20/100
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0025 - mean_absolute_error: 0.0404 - val_loss: 8.7412e-04 - val_mean_absolute_error: 0.0260
# Epoch 21/100
# 33/33 [==============================] - 0s 7ms/step - loss: 0.0024 - mean_absolute_error: 0.0399 - val_loss: 8.4295e-04 - val_mean_absolute_error: 0.0255
# Epoch 22/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0023 - mean_absolute_error: 0.0394 - val_loss: 0.0011 - val_mean_absolute_error: 0.0302
# Epoch 23/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0022 - mean_absolute_error: 0.0383 - val_loss: 0.0014 - val_mean_absolute_error: 0.0352
# Epoch 24/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0021 - mean_absolute_error: 0.0376 - val_loss: 9.3878e-04 - val_mean_absolute_error: 0.0275
# Epoch 25/100
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0020 - mean_absolute_error: 0.0366 - val_loss: 9.2283e-04 - val_mean_absolute_error: 0.0273
# Epoch 26/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0019 - mean_absolute_error: 0.0361 - val_loss: 7.8081e-04 - val_mean_absolute_error: 0.0249
# Epoch 27/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0017 - mean_absolute_error: 0.0336 - val_loss: 5.0589e-04 - val_mean_absolute_error: 0.0194
# Epoch 28/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0015 - mean_absolute_error: 0.0319 - val_loss: 6.6337e-04 - val_mean_absolute_error: 0.0232
# Epoch 29/100
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0013 - mean_absolute_error: 0.0296 - val_loss: 1.9597e-04 - val_mean_absolute_error: 0.0111
# Epoch 30/100
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0012 - mean_absolute_error: 0.0280 - val_loss: 6.0014e-04 - val_mean_absolute_error: 0.0224
# Epoch 31/100
# 33/33 [==============================] - 0s 8ms/step - loss: 9.3312e-04 - mean_absolute_error: 0.0250 - val_loss: 5.4388e-04 - val_mean_absolute_error: 0.0214
# Epoch 32/100
# 33/33 [==============================] - 0s 8ms/step - loss: 6.8978e-04 - mean_absolute_error: 0.0214 - val_loss: 4.2300e-04 - val_mean_absolute_error: 0.0188
# Epoch 33/100
# 33/33 [==============================] - 0s 10ms/step - loss: 5.7835e-04 - mean_absolute_error: 0.0195 - val_loss: 1.0629e-04 - val_mean_absolute_error: 0.0087
# Epoch 34/100
# 33/33 [==============================] - 0s 8ms/step - loss: 3.2951e-04 - mean_absolute_error: 0.0146 - val_loss: 8.5647e-05 - val_mean_absolute_error: 0.0079
# Epoch 35/100
# 33/33 [==============================] - 0s 6ms/step - loss: 1.8794e-04 - mean_absolute_error: 0.0110 - val_loss: 6.0412e-05 - val_mean_absolute_error: 0.0065
# Epoch 36/100
# 33/33 [==============================] - 0s 6ms/step - loss: 1.0783e-04 - mean_absolute_error: 0.0081 - val_loss: 4.5228e-05 - val_mean_absolute_error: 0.0054
# Epoch 37/100
# 33/33 [==============================] - 0s 6ms/step - loss: 7.8395e-05 - mean_absolute_error: 0.0068 - val_loss: 6.0185e-05 - val_mean_absolute_error: 0.0065
# Epoch 38/100
# 33/33 [==============================] - 0s 6ms/step - loss: 7.0900e-05 - mean_absolute_error: 0.0065 - val_loss: 6.7514e-05 - val_mean_absolute_error: 0.0069
# Epoch 39/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.4092e-05 - mean_absolute_error: 0.0061 - val_loss: 5.0732e-05 - val_mean_absolute_error: 0.0058
# Epoch 40/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.9636e-05 - mean_absolute_error: 0.0060 - val_loss: 5.1975e-05 - val_mean_absolute_error: 0.0059
# Epoch 41/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.5282e-05 - mean_absolute_error: 0.0056 - val_loss: 4.1763e-05 - val_mean_absolute_error: 0.0051
# Epoch 42/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.7549e-05 - mean_absolute_error: 0.0058 - val_loss: 5.1184e-05 - val_mean_absolute_error: 0.0059
# Epoch 43/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.9905e-05 - mean_absolute_error: 0.0059 - val_loss: 4.3777e-05 - val_mean_absolute_error: 0.0053
# Epoch 44/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.5804e-05 - mean_absolute_error: 0.0056 - val_loss: 4.2392e-05 - val_mean_absolute_error: 0.0052
# Epoch 45/100
# 33/33 [==============================] - 0s 5ms/step - loss: 6.6554e-05 - mean_absolute_error: 0.0063 - val_loss: 8.7945e-05 - val_mean_absolute_error: 0.0076
# Epoch 46/100
# 33/33 [==============================] - 0s 6ms/step - loss: 9.1816e-05 - mean_absolute_error: 0.0076 - val_loss: 6.4589e-05 - val_mean_absolute_error: 0.0068
# Epoch 47/100
# 33/33 [==============================] - 0s 6ms/step - loss: 9.4918e-05 - mean_absolute_error: 0.0079 - val_loss: 9.7023e-05 - val_mean_absolute_error: 0.0080
# Epoch 48/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.2092e-05 - mean_absolute_error: 0.0061 - val_loss: 4.1813e-05 - val_mean_absolute_error: 0.0052
# Epoch 49/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.8325e-05 - mean_absolute_error: 0.0059 - val_loss: 5.7077e-05 - val_mean_absolute_error: 0.0062
# Epoch 50/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.9273e-05 - mean_absolute_error: 0.0059 - val_loss: 6.3203e-05 - val_mean_absolute_error: 0.0061
# Epoch 51/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.5207e-05 - mean_absolute_error: 0.0062 - val_loss: 4.1900e-05 - val_mean_absolute_error: 0.0051
# Epoch 52/100
# 33/33 [==============================] - 0s 7ms/step - loss: 5.7849e-05 - mean_absolute_error: 0.0057 - val_loss: 9.7641e-05 - val_mean_absolute_error: 0.0081
# Epoch 53/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.8570e-05 - mean_absolute_error: 0.0058 - val_loss: 4.6498e-05 - val_mean_absolute_error: 0.0053
# Epoch 54/100
# 33/33 [==============================] - 0s 5ms/step - loss: 6.6023e-05 - mean_absolute_error: 0.0063 - val_loss: 4.8171e-05 - val_mean_absolute_error: 0.0057
# Epoch 55/100
# 33/33 [==============================] - 0s 5ms/step - loss: 6.3062e-05 - mean_absolute_error: 0.0062 - val_loss: 4.7305e-05 - val_mean_absolute_error: 0.0056
# Epoch 56/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.1988e-05 - mean_absolute_error: 0.0059 - val_loss: 4.1294e-05 - val_mean_absolute_error: 0.0051
# Epoch 57/100
# 33/33 [==============================] - 0s 7ms/step - loss: 6.5277e-05 - mean_absolute_error: 0.0062 - val_loss: 4.2211e-05 - val_mean_absolute_error: 0.0052
# Epoch 58/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.4344e-05 - mean_absolute_error: 0.0063 - val_loss: 4.4014e-05 - val_mean_absolute_error: 0.0052
# Epoch 59/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.4186e-05 - mean_absolute_error: 0.0062 - val_loss: 5.1844e-05 - val_mean_absolute_error: 0.0056
# Epoch 60/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.3736e-05 - mean_absolute_error: 0.0062 - val_loss: 5.3992e-05 - val_mean_absolute_error: 0.0057
# Epoch 61/100
# 33/33 [==============================] - 0s 7ms/step - loss: 6.0481e-05 - mean_absolute_error: 0.0060 - val_loss: 5.4178e-05 - val_mean_absolute_error: 0.0058
# Epoch 62/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.7350e-05 - mean_absolute_error: 0.0058 - val_loss: 4.1413e-05 - val_mean_absolute_error: 0.0051
# Epoch 63/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.3039e-05 - mean_absolute_error: 0.0056 - val_loss: 4.5830e-05 - val_mean_absolute_error: 0.0055
# Epoch 64/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.0382e-05 - mean_absolute_error: 0.0060 - val_loss: 6.5709e-05 - val_mean_absolute_error: 0.0063
# Epoch 65/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.3150e-05 - mean_absolute_error: 0.0061 - val_loss: 4.4291e-05 - val_mean_absolute_error: 0.0052
# Epoch 66/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.7583e-05 - mean_absolute_error: 0.0064 - val_loss: 4.2586e-05 - val_mean_absolute_error: 0.0052
# Epoch 67/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.4221e-05 - mean_absolute_error: 0.0056 - val_loss: 4.2465e-05 - val_mean_absolute_error: 0.0051
# Epoch 68/100
# 33/33 [==============================] - 0s 6ms/step - loss: 7.4111e-05 - mean_absolute_error: 0.0067 - val_loss: 4.1285e-05 - val_mean_absolute_error: 0.0051
# Epoch 69/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.2529e-05 - mean_absolute_error: 0.0061 - val_loss: 5.2340e-05 - val_mean_absolute_error: 0.0060
# Epoch 70/100
# 33/33 [==============================] - 0s 5ms/step - loss: 7.2700e-05 - mean_absolute_error: 0.0067 - val_loss: 4.1930e-05 - val_mean_absolute_error: 0.0052
# Epoch 71/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.8550e-05 - mean_absolute_error: 0.0060 - val_loss: 4.3973e-05 - val_mean_absolute_error: 0.0053
# Epoch 72/100
# 33/33 [==============================] - 0s 7ms/step - loss: 6.9406e-05 - mean_absolute_error: 0.0066 - val_loss: 4.3812e-05 - val_mean_absolute_error: 0.0053
# Epoch 73/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.4879e-05 - mean_absolute_error: 0.0057 - val_loss: 5.1285e-05 - val_mean_absolute_error: 0.0055
# Epoch 74/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.2126e-05 - mean_absolute_error: 0.0061 - val_loss: 4.5653e-05 - val_mean_absolute_error: 0.0053
# Epoch 75/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.7220e-05 - mean_absolute_error: 0.0058 - val_loss: 5.8216e-05 - val_mean_absolute_error: 0.0063
# Epoch 76/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.5178e-05 - mean_absolute_error: 0.0063 - val_loss: 4.2301e-05 - val_mean_absolute_error: 0.0051
# Epoch 77/100
# 33/33 [==============================] - 0s 5ms/step - loss: 6.3311e-05 - mean_absolute_error: 0.0062 - val_loss: 4.4412e-05 - val_mean_absolute_error: 0.0052
# Epoch 78/100
# 33/33 [==============================] - 0s 6ms/step - loss: 7.8098e-05 - mean_absolute_error: 0.0070 - val_loss: 1.0822e-04 - val_mean_absolute_error: 0.0090
# Epoch 79/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.7877e-05 - mean_absolute_error: 0.0065 - val_loss: 8.0974e-05 - val_mean_absolute_error: 0.0076
# Epoch 80/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.6921e-05 - mean_absolute_error: 0.0063 - val_loss: 4.2441e-05 - val_mean_absolute_error: 0.0052
# Epoch 81/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.8151e-05 - mean_absolute_error: 0.0059 - val_loss: 4.7741e-05 - val_mean_absolute_error: 0.0056
# Epoch 82/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.0266e-05 - mean_absolute_error: 0.0060 - val_loss: 4.3116e-05 - val_mean_absolute_error: 0.0053
# Epoch 83/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.0901e-05 - mean_absolute_error: 0.0060 - val_loss: 4.5781e-05 - val_mean_absolute_error: 0.0055
# Epoch 84/100
# 33/33 [==============================] - 0s 8ms/step - loss: 5.7764e-05 - mean_absolute_error: 0.0058 - val_loss: 6.7324e-05 - val_mean_absolute_error: 0.0068
# Epoch 85/100
# 33/33 [==============================] - 0s 8ms/step - loss: 6.0186e-05 - mean_absolute_error: 0.0059 - val_loss: 4.1850e-05 - val_mean_absolute_error: 0.0052
# Epoch 86/100
# 33/33 [==============================] - 0s 9ms/step - loss: 6.1794e-05 - mean_absolute_error: 0.0061 - val_loss: 5.6628e-05 - val_mean_absolute_error: 0.0062
# Epoch 87/100
# 33/33 [==============================] - 0s 8ms/step - loss: 5.7413e-05 - mean_absolute_error: 0.0058 - val_loss: 5.1492e-05 - val_mean_absolute_error: 0.0055
# Epoch 88/100
# 33/33 [==============================] - 0s 8ms/step - loss: 5.8651e-05 - mean_absolute_error: 0.0059 - val_loss: 4.2248e-05 - val_mean_absolute_error: 0.0052
# Epoch 89/100
# 33/33 [==============================] - 0s 9ms/step - loss: 5.8295e-05 - mean_absolute_error: 0.0059 - val_loss: 4.8489e-05 - val_mean_absolute_error: 0.0054
# Epoch 90/100
# 33/33 [==============================] - 0s 8ms/step - loss: 7.0297e-05 - mean_absolute_error: 0.0065 - val_loss: 4.3250e-05 - val_mean_absolute_error: 0.0053
# Epoch 91/100
# 33/33 [==============================] - 0s 9ms/step - loss: 5.4328e-05 - mean_absolute_error: 0.0056 - val_loss: 4.8731e-05 - val_mean_absolute_error: 0.0057
# Epoch 92/100
# 33/33 [==============================] - 0s 9ms/step - loss: 6.6366e-05 - mean_absolute_error: 0.0063 - val_loss: 3.2542e-04 - val_mean_absolute_error: 0.0169
# Epoch 93/100
# 33/33 [==============================] - 0s 7ms/step - loss: 1.0273e-04 - mean_absolute_error: 0.0080 - val_loss: 6.3071e-05 - val_mean_absolute_error: 0.0061
# Epoch 94/100
# 33/33 [==============================] - 0s 5ms/step - loss: 5.6783e-05 - mean_absolute_error: 0.0058 - val_loss: 4.2395e-05 - val_mean_absolute_error: 0.0051
# Epoch 95/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.5434e-05 - mean_absolute_error: 0.0057 - val_loss: 7.3705e-05 - val_mean_absolute_error: 0.0067
# Epoch 96/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.1538e-05 - mean_absolute_error: 0.0061 - val_loss: 5.7749e-05 - val_mean_absolute_error: 0.0058
# Epoch 97/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.9365e-05 - mean_absolute_error: 0.0064 - val_loss: 4.1695e-05 - val_mean_absolute_error: 0.0051
# Epoch 98/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.6419e-05 - mean_absolute_error: 0.0058 - val_loss: 4.1653e-05 - val_mean_absolute_error: 0.0051
# Epoch 99/100
# 33/33 [==============================] - 0s 6ms/step - loss: 6.7010e-05 - mean_absolute_error: 0.0063 - val_loss: 5.9503e-05 - val_mean_absolute_error: 0.0064
# Epoch 100/100
# 33/33 [==============================] - 0s 6ms/step - loss: 5.6790e-05 - mean_absolute_error: 0.0058 - val_loss: 4.2037e-05 - val_mean_absolute_error: 0.0052
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
from sklearn.metrics import mean_squared_error

train_predictions = model.predict(X_train).flatten()
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 33/33 [==============================] - 0s 2ms/step

# %%
import numpy as np
basis_point_value=0.0001  #For EURUSD pair
train_data_basis_point_diff=((train_predictions/basis_point_value).flatten()-y_train/basis_point_value).abs()
plt.plot(dates_train, train_data_basis_point_diff)

average_train_data_basis_point_diff=np.mean(train_data_basis_point_diff)
print(average_train_data_basis_point_diff)
# Out:
# 54.157060934474856

# %%
val_predictions = model.predict(X_val).flatten()
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 5/5 [==============================] - 0s 8ms/step

# %%
basis_point_value=0.0001  #For EURUSD pair
validation_data_basis_point_diff=((val_predictions/basis_point_value).flatten()-y_val/basis_point_value).abs()
plt.plot(dates_val, validation_data_basis_point_diff)

print(np.mean(validation_data_basis_point_diff))
# Out:
# 51.94527040939939

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 5/5 [==============================] - 0s 3ms/step

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# Assuming test_predictions and y_test are lists or numpy arrays
# Calculate MSE and MAE
mse = mean_squared_error(y_test, test_predictions)
print("Mean Square Error:", mse)
mae=mean_absolute_error(y_test, test_predictions)
print("Mean Absolute Error:", mae)
# Out:
# Mean Square Error: 2.1838535430971848e-05
# Mean Absolute Error: 0.003603745321713952

# %%
basis_point_value=0.0001  #For EURUSD pair
test_data_basis_point_diff=((test_predictions/basis_point_value).flatten()-y_test/basis_point_value).abs()
plt.plot(dates_test, test_data_basis_point_diff)

print(np.mean(test_data_basis_point_diff))
# Out:
# 36.03747145432686

# %%
#Start Trading with 1000 USD with model


number_of_trading_days=dates_test.size
test_data=y_test.values
holding_currency="quote"
holding_value=1000
for current_trading_day in range(number_of_trading_days-1):
  if holding_currency=="quote":
    if (test_predictions[current_trading_day+1]>test_data[current_trading_day]):
      holding_value=holding_value/test_data[current_trading_day]
      holding_currency="base"
  else:
    if (test_predictions[current_trading_day+1]<test_data[current_trading_day]):
      holding_value=test_data[current_trading_day]*holding_value
      holding_currency="quote"


if holding_currency=="base":
  holding_value=test_data[current_trading_day]*holding_value

print(number_of_trading_days)
print(holding_value)
print(holding_currency)
# Out:
# 130
# 1025.1917326326875
# base

# %%
#Start Trading with 1000 USD with actual values


number_of_trading_days=dates_test.size
test_data=y_test.values
holding_currency="quote"
holding_value=1000
for current_trading_day in range(number_of_trading_days-1):
  if holding_currency=="quote":
    if (test_data[current_trading_day+1]>test_data[current_trading_day]):
      holding_value=holding_value/test_data[current_trading_day]
      holding_currency="base"
  else:
    if (test_data[current_trading_day+1]<test_data[current_trading_day]):
      holding_value=test_data[current_trading_day]*holding_value
      holding_currency="quote"


if holding_currency=="base":
  holding_value=test_data[current_trading_day]*holding_value

print(number_of_trading_days)
print(holding_value)
print(holding_currency)
# Out:
# 130
# 1162.4703444056145
# quote

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction
# Out:
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 42ms/step
# 1/1 [==============================] - 0s 33ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 46ms/step
# 1/1 [==============================] - 0s 35ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 29ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 19ms/step

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
