# %% [markdown]
# <a href="https://colab.research.google.com/github/cepdnaclk/e18-4yp-Predicting-Forex-Currency-Exchange-Rate-using-Machine-Learning/blob/main/models/GBPUSD/GBPUSD_IN2_LSTM_GRID_Version.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas_ta
# Out:
# Collecting pandas_ta
#   Downloading pandas_ta-0.3.14b.tar.gz (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.1/115.1 kB 1.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from pandas_ta) (2.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (2024.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas->pandas_ta) (1.25.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->pandas_ta) (1.16.0)
# Building wheels for collected packages: pandas_ta
#   Building wheel for pandas_ta (setup.py) ... done
#   Created wheel for pandas_ta: filename=pandas_ta-0.3.14b0-py3-none-any.whl size=218907 sha256=f59207392e9008d6090afdf36c59e07afa660c8727666bcb46d51d896ba59c13
#   Stored in directory: /root/.cache/pip/wheels/69/00/ac/f7fa862c34b0e2ef320175100c233377b4c558944f12474cf0
# Successfully built pandas_ta
# Installing collected packages: pandas_ta
# Successfully installed pandas_ta-0.3.14b0

# %%
import pandas as pd
import pandas_ta as ta

data = pd.read_csv('GBPUSD=X.csv')

data
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume
# 0     2019-07-04  1.258384  1.259287  1.257055  1.258273   1.258273       0
# 1     2019-07-05  1.258336  1.258701  1.248299  1.258305   1.258305       0
# 2     2019-07-08  1.252615  1.254076  1.250125  1.252552   1.252552       0
# 3     2019-07-09  1.251878  1.252035  1.244122  1.251643   1.251643       0
# 4     2019-07-10  1.245733  1.252113  1.244524  1.245858   1.245858       0
# ...          ...       ...       ...       ...       ...        ...     ...
# 1301  2024-06-28  1.264382  1.266175  1.262021  1.264574   1.264574       0
# 1302  2024-07-01  1.265022  1.269535  1.263743  1.264862   1.264862       0
# 1303  2024-07-02  1.264622  1.268536  1.261639  1.264574   1.264574       0
# 1304  2024-07-03  1.268810  1.277710  1.267909  1.269036   1.269036       0
# 1305  2024-07-04  1.274486  1.276732  1.274177  1.276308   1.276308       0
#
# [1306 rows x 7 columns]

# %%
data['T-4'] = data['Close']
data['T-3'] = data['Close'].shift(-1)
data['T-2'] = data['Close'].shift(-2)
data['T-1'] = data['Close'].shift(-3)
data['T0'] = data['Close'].shift(-4)

# data['SMA_5_H'] = ta.sma(data['High'], length=5).shift(-4)
# data['SMA_5_L'] = ta.sma(data['Low'], length=5).shift(-4)
data['EMA_5_C'] = ta.ema(data['Close'], length=5).shift(-4)
data['RSI'] = ta.rsi(data['Close'], length=14).shift(-14)

#Closing value of the next day
data['T_F'] = data['Close'].shift(-5)

print(data.head(10))
# Out:
#          Date      Open      High       Low     Close  Adj Close  Volume  \
# 0  2019-07-04  1.258384  1.259287  1.257055  1.258273   1.258273       0
# 1  2019-07-05  1.258336  1.258701  1.248299  1.258305   1.258305       0
# 2  2019-07-08  1.252615  1.254076  1.250125  1.252552   1.252552       0
# 3  2019-07-09  1.251878  1.252035  1.244122  1.251643   1.251643       0
# 4  2019-07-10  1.245733  1.252113  1.244524  1.245858   1.245858       0
# 5  2019-07-11  1.250625  1.257229  1.250625  1.250813   1.250813       0
# 6  2019-07-12  1.252270  1.256266  1.252270  1.252348   1.252348       0
# 7  2019-07-15  1.257229  1.257640  1.251189  1.257197   1.257197       0
# 8  2019-07-16  1.252035  1.252035  1.239741  1.251799   1.251799       0
# 9  2019-07-17  1.240880  1.243936  1.238344  1.241203   1.241203       0
#
#         T-4       T-3       T-2       T-1        T0   EMA_5_C        RSI  \
# 0  1.258273  1.258305  1.252552  1.251643  1.245858  1.253326  38.986487
# 1  1.258305  1.252552  1.251643  1.245858  1.250813  1.252488  45.472080
# 2  1.252552  1.251643  1.245858  1.250813  1.252348  1.252442  42.130046
# 3  1.251643  1.245858  1.250813  1.252348  1.257197  1.254027  35.495401
# 4  1.245858  1.250813  1.252348  1.257197  1.251799  1.253284  26.256917
# 5  1.250813  1.252348  1.257197  1.251799  1.241203  1.249257  23.905819
# 6  1.252348  1.257197  1.251799  1.241203  1.243472  1.247329  23.587056
# 7  1.257197  1.251799  1.241203  1.243472  1.254186  1.249614  22.377623
# 8  1.251799  1.241203  1.243472  1.254186  1.251283  1.250171  26.226064
# 9  1.241203  1.243472  1.254186  1.251283  1.247489  1.249277  27.073624
#
#         T_F
# 0  1.250813
# 1  1.252348
# 2  1.257197
# 3  1.251799
# 4  1.241203
# 5  1.243472
# 6  1.254186
# 7  1.251283
# 8  1.247489
# 9  1.243905

# %%
#MACD calculation
# Calculate the 12-period EMA
data['EMA_12'] = data['Close'].ewm(span=12, adjust=False).mean()

# Calculate the 26-period EMA
data['EMA_26'] = data['Close'].ewm(span=26, adjust=False).mean()

# Calculate the MACD Line
data['MACD_Line'] = data['EMA_12'] - data['EMA_26']

# Calculate the Signal Line (9-period EMA of the MACD Line)
data['Signal_Line'] = data['MACD_Line'].ewm(span=9, adjust=False).mean()

# Calculate the MACD Histogram
data['MACD_Histogram'] = data['MACD_Line'] - data['Signal_Line']

# %%
#ROC Calculations

# Calculate the 2 day ROC
data['ROC2'] = ((data['Close'] - data['Close'].shift(2)) / data['Close'].shift(2)) * 100

# Calculate the 4 day ROC
data['ROC4'] = ((data['Close'] - data['Close'].shift(4)) / data['Close'].shift(4)) * 100

# Calculate the 10 day ROC
data['ROC10'] = ((data['Close'] - data['Close'].shift(10)) / data['Close'].shift(10)) * 100

# %%
print(data.tail(10))
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume  \
# 1296  2024-06-21  1.266047  1.266978  1.262563  1.266047   1.266047       0
# 1297  2024-06-24  1.263967  1.269841  1.263360  1.263903   1.263903       0
# 1298  2024-06-25  1.268311  1.270245  1.267154  1.268343   1.268343       0
# 1299  2024-06-26  1.268472  1.269197  1.262084  1.268400   1.268400       0
# 1300  2024-06-27  1.262148  1.266945  1.261352  1.262180   1.262180       0
# 1301  2024-06-28  1.264382  1.266175  1.262021  1.264574   1.264574       0
# 1302  2024-07-01  1.265022  1.269535  1.263743  1.264862   1.264862       0
# 1303  2024-07-02  1.264622  1.268536  1.261639  1.264574   1.264574       0
# 1304  2024-07-03  1.268810  1.277710  1.267909  1.269036   1.269036       0
# 1305  2024-07-04  1.274486  1.276732  1.274177  1.276308   1.276308       0
#
#            T-4       T-3       T-2  ...  RSI       T_F    EMA_12    EMA_26  \
# 1296  1.266047  1.263903  1.268343  ...  NaN  1.264574  1.271990  1.270609
# 1297  1.263903  1.268343  1.268400  ...  NaN  1.264862  1.270746  1.270112
# 1298  1.268343  1.268400  1.262180  ...  NaN  1.264574  1.270376  1.269981
# 1299  1.268400  1.262180  1.264574  ...  NaN  1.269036  1.270072  1.269864
# 1300  1.262180  1.264574  1.264862  ...  NaN  1.276308  1.268858  1.269295
# 1301  1.264574  1.264862  1.264574  ...  NaN       NaN  1.268199  1.268945
# 1302  1.264862  1.264574  1.269036  ...  NaN       NaN  1.267686  1.268643
# 1303  1.264574  1.269036  1.276308  ...  NaN       NaN  1.267207  1.268341
# 1304  1.269036  1.276308       NaN  ...  NaN       NaN  1.267488  1.268393
# 1305  1.276308       NaN       NaN  ...  NaN       NaN  1.268845  1.268979
#
#       MACD_Line  Signal_Line  MACD_Histogram      ROC2      ROC4     ROC10
# 1296   0.001381     0.002985       -0.001604 -0.369704 -0.178505 -1.038200
# 1297   0.000633     0.002515       -0.001881 -0.652177 -0.605300 -0.710321
# 1298   0.000395     0.002091       -0.001696  0.181352 -0.189023 -0.337410
# 1299   0.000208     0.001714       -0.001506  0.355803 -0.298695 -0.443311
# 1300  -0.000437     0.001284       -0.001721 -0.485910 -0.305439 -1.363136
# 1301  -0.000746     0.000878       -0.001624 -0.301640  0.053090 -0.857383
# 1302  -0.000957     0.000511       -0.001468  0.212490 -0.274453 -0.271936
# 1303  -0.001135     0.000182       -0.001316  0.000000 -0.301640 -0.552532
# 1304  -0.000905    -0.000036       -0.000869  0.329996  0.543187 -0.134488
# 1305  -0.000134    -0.000055       -0.000079  0.927901  0.927901  0.322905
#
# [10 rows x 23 columns]

# %%
# Dropping NaN values
data.dropna(inplace=True)

print(data.tail(10))
# Out:
#             Date      Open      High       Low     Close  Adj Close  Volume  \
# 1282  2024-06-03  1.274405  1.279394  1.269551  1.274372   1.274372       0
# 1283  2024-06-04  1.281017  1.281723  1.274437  1.281017   1.281017       0
# 1284  2024-06-05  1.277302  1.279525  1.275771  1.277302   1.277302       0
# 1285  2024-06-06  1.279394  1.281066  1.276552  1.279476   1.279476       0
# 1286  2024-06-07  1.279427  1.281082  1.271747  1.279329   1.279329       0
# 1287  2024-06-10  1.272870  1.273237  1.268907  1.272945   1.272945       0
# 1288  2024-06-11  1.272588  1.274941  1.270761  1.272637   1.272637       0
# 1289  2024-06-12  1.273837  1.286008  1.273360  1.274048   1.274048       0
# 1290  2024-06-13  1.279673  1.280607  1.275283  1.279623   1.279623       0
# 1291  2024-06-14  1.275445  1.276487  1.265807  1.275510   1.275510       0
#
#            T-4       T-3       T-2  ...        RSI       T_F    EMA_12  \
# 1282  1.274372  1.281017  1.277302  ...  44.972287  1.272945  1.270574
# 1283  1.281017  1.277302  1.279476  ...  42.870676  1.272637  1.272180
# 1284  1.277302  1.279476  1.279329  ...  48.262726  1.274048  1.272968
# 1285  1.279476  1.279329  1.272945  ...  48.330149  1.279623  1.273969
# 1286  1.279329  1.272945  1.272637  ...  41.911566  1.275510  1.274794
# 1287  1.272945  1.272637  1.274048  ...  44.942364  1.268311  1.274510
# 1288  1.272637  1.274048  1.279623  ...  45.312032  1.271600  1.274221
# 1289  1.274048  1.279623  1.275510  ...  44.986748  1.270745  1.274195
# 1290  1.279623  1.275510  1.268311  ...  50.871227  1.272200  1.275030
# 1291  1.275510  1.268311  1.271600  ...  58.636655  1.266047  1.275104
#
#         EMA_26  MACD_Line  Signal_Line  MACD_Histogram      ROC2      ROC4  \
# 1282  1.265444   0.005129     0.004521        0.000608  0.360136 -0.224312
# 1283  1.266598   0.005582     0.004733        0.000849  0.626452  0.406087
# 1284  1.267391   0.005577     0.004902        0.000675  0.229917  0.590881
# 1285  1.268286   0.005683     0.005059        0.000625 -0.120295  0.505404
# 1286  1.269104   0.005690     0.005185        0.000505  0.158694  0.388976
# 1287  1.269389   0.005121     0.005172       -0.000051 -0.510443 -0.630124
# 1288  1.269629   0.004592     0.005056       -0.000464 -0.523087 -0.365223
# 1289  1.269957   0.004238     0.004893       -0.000654  0.086649 -0.424236
# 1290  1.270673   0.004357     0.004785       -0.000428  0.548939  0.022981
# 1291  1.271031   0.004073     0.004643       -0.000570  0.114752  0.201501
#
#          ROC10
# 1282  0.293079
# 1283  0.781459
# 1284  0.485315
# 1285  0.579591
# 1286  0.781704
# 1287 -0.052214
# 1288 -0.360152
# 1289 -0.140143
# 1290  0.773666
# 1291  0.193866
#
# [10 rows x 23 columns]

# %%
data = data[['Date', 'T-4','T-3','T-2','T-1','T0','EMA_5_C','RSI','MACD_Histogram','ROC2','ROC4','ROC10','T_F']]

data
# Out:
#             Date       T-4       T-3       T-2       T-1        T0   EMA_5_C  \
# 10    2019-07-18  1.243472  1.254186  1.251283  1.247489  1.243905  1.247486
# 11    2019-07-19  1.254186  1.251283  1.247489  1.243905  1.248595  1.247856
# 12    2019-07-22  1.251283  1.247489  1.243905  1.248595  1.245345  1.247019
# 13    2019-07-23  1.247489  1.243905  1.248595  1.245345  1.237670  1.243903
# 14    2019-07-24  1.243905  1.248595  1.245345  1.237670  1.221747  1.236517
# ...          ...       ...       ...       ...       ...       ...       ...
# 1287  2024-06-10  1.272945  1.272637  1.274048  1.279623  1.275510  1.276087
# 1288  2024-06-11  1.272637  1.274048  1.279623  1.275510  1.268311  1.273495
# 1289  2024-06-12  1.274048  1.279623  1.275510  1.268311  1.271600  1.272863
# 1290  2024-06-13  1.279623  1.275510  1.268311  1.271600  1.270745  1.272157
# 1291  2024-06-14  1.275510  1.268311  1.271600  1.270745  1.272200  1.272171
#
#             RSI  MACD_Histogram      ROC2      ROC4     ROC10       T_F
# 10    28.752261       -0.001225 -0.665203 -0.708749 -1.176295  1.248595
# 11    27.206476       -0.000583  1.046001 -0.239501 -0.327345  1.245345
# 12    27.276519       -0.000318  0.628161 -0.041221 -0.101313  1.237670
# 13    21.198342       -0.000360 -0.533972  0.506444 -0.331884  1.221747
# 14    29.128644       -0.000576 -0.589635  0.034822 -0.156759  1.216160
# ...         ...             ...       ...       ...       ...       ...
# 1287  44.942364       -0.000051 -0.510443 -0.630124 -0.052214  1.268311
# 1288  45.312032       -0.000464 -0.523087 -0.365223 -0.360152  1.271600
# 1289  44.986748       -0.000654  0.086649 -0.424236 -0.140143  1.270745
# 1290  50.871227       -0.000428  0.548939  0.022981  0.773666  1.272200
# 1291  58.636655       -0.000570  0.114752  0.201501  0.193866  1.266047
#
# [1282 rows x 13 columns]

# %%
import matplotlib.pyplot as plt

plt.plot(data.index, data['T_F'])

# %%
dates=data['Date'].to_numpy()
middle_matrix =data[['T-4','T-3','T-2','T-1','T0','EMA_5_C','RSI','MACD_Histogram','ROC2','ROC4','ROC10']].to_numpy()
X = middle_matrix.reshape((len(dates), middle_matrix.shape[1], 1))
Y=data['T_F']

print(dates.shape)
print(X.shape)
print(Y.shape)
# Out:
# (1282,)
# (1282, 11, 1)
# (1282,)

# %%
q_80 = int(len(dates) * .8) #change to 0.8
q_90 = int(len(dates) * .9)

dates_train, X_train, y_train = dates[:q_80], X[:q_80], Y[:q_80]

dates_val, X_val, y_val = dates[q_80:q_90], X[q_80:q_90], Y[q_80:q_90]
dates_test, X_test, y_test = dates[q_90:], X[q_90:], Y[q_90:]

plt.plot(dates_train, y_train)
plt.plot(dates_val, y_val)
plt.plot(dates_test, y_test)

plt.legend(['Train', 'Validation', 'Test'])

# %%
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.optimizers import Adam
# from tensorflow.keras import layers

# # model = Sequential([layers.Input((9, 1)),
# #                     layers.LSTM(300),
# #                     layers.Dense(1)])

# model = Sequential([layers.Input((9, 1)),
#                    layers.LSTM(64),
#                    layers.Dense(10, activation='relu'),
#                    layers.Dense(10, activation='relu'),
#                    layers.Dense(1)])

# model.compile(loss='mse',
#               optimizer=Adam(learning_rate=0.01),
#               metrics=['mean_absolute_error'])

# model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=50)

import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

# Define different parameter values to iterate over
epochs_values = [100, 150]
lstm_units_values = [10, 20, 50]
learning_rate_values = [0.01, 0.001, 0.0001]
dense1_values = [10, 50, 100]
dense2_values = [10, 50, 100]

best_loss = float('inf')
best_epochs = None
best_lstm_units = None
best_learning_rate = None
best_dense2 = None
best_dense1 = None
hist = []

# Define X_train, y_train, X_val, y_val

# Loop over different parameter combinations
for epochs in epochs_values:
    for lstm_units in lstm_units_values:
        for learning_rate in learning_rate_values:
          for dense1 in dense1_values:
            for dense2 in dense2_values:
                print(f"Training model with epochs={epochs}, lstm_units={lstm_units}, learning_rate={learning_rate}")

                # model = Sequential([layers.Input((9, 1)),
                #         layers.LSTM(lstm_units),
                #         layers.Dense(1)])

                # Define the model
                model = Sequential([
                    layers.Input((11, 1)),
                    layers.LSTM(lstm_units),
                    layers.Dense(dense1, activation='relu'),
                    layers.Dense(dense2, activation='relu'),
                    layers.Dense(1)
                ])

                model.compile(loss='mse',
                              optimizer=Adam(learning_rate=learning_rate),
                              metrics=['mean_absolute_error'])

                # Train the model
                history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=epochs, verbose=0)

                # Check if this combination has the best validation loss so far
                if history.history['loss'][-1] < best_loss:
                    hist = history.history
                    best_loss = history.history['loss'][-1]
                    best_epochs = epochs
                    best_lstm_units = lstm_units
                    best_learning_rate = learning_rate
                    best_dense1 = dense1
                    best_dense2 = dense2

# Print the best combination
print(f"Best combination: epochs={best_epochs}, lstm_units={best_lstm_units}, learning_rate={best_learning_rate}, Validation Loss={best_loss}, best_dense1={best_dense1}, best_dense2={best_dense2}")
# Out:
# Training model with epochs=100, lstm_units=10, learning_rate=0.01
# Training model with epochs=100, lstm_units=10, learning_rate=0.01
# Training model with epochs=100, lstm_units=10, learning_rate=0.01
# Training model with epochs=100, lstm_units=10, learning_rate=0.01
# Training model with epochs=100, lstm_units=10, learning_rate=0.01
# Training model with epochs=100, lstm_units=10, learning_rate=0.01
# Training model with epochs=100, lstm_units=10, learning_rate=0.01
# Training model with epochs=100, lstm_units=10, learning_rate=0.01
# Training model with epochs=100, lstm_units=10, learning_rate=0.01
# Training model with epochs=100, lstm_units=10, learning_rate=0.001
# Training model with epochs=100, lstm_units=10, learning_rate=0.001
# Training model with epochs=100, lstm_units=10, learning_rate=0.001
# Training model with epochs=100, lstm_units=10, learning_rate=0.001
# Training model with epochs=100, lstm_units=10, learning_rate=0.001
# Training model with epochs=100, lstm_units=10, learning_rate=0.001
# Training model with epochs=100, lstm_units=10, learning_rate=0.001
# Training model with epochs=100, lstm_units=10, learning_rate=0.001
# Training model with epochs=100, lstm_units=10, learning_rate=0.001
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001
# Training model with epochs=100, lstm_units=10, learning_rate=0.0001
# Training model with epochs=100, lstm_units=20, learning_rate=0.01
# Training model with epochs=100, lstm_units=20, learning_rate=0.01
# Training model with epochs=100, lstm_units=20, learning_rate=0.01
# Training model with epochs=100, lstm_units=20, learning_rate=0.01
# Training model with epochs=100, lstm_units=20, learning_rate=0.01
# Training model with epochs=100, lstm_units=20, learning_rate=0.01
# Training model with epochs=100, lstm_units=20, learning_rate=0.01
# Training model with epochs=100, lstm_units=20, learning_rate=0.01
# Training model with epochs=100, lstm_units=20, learning_rate=0.01
# Training model with epochs=100, lstm_units=20, learning_rate=0.001
# Training model with epochs=100, lstm_units=20, learning_rate=0.001
# Training model with epochs=100, lstm_units=20, learning_rate=0.001
# Training model with epochs=100, lstm_units=20, learning_rate=0.001
# Training model with epochs=100, lstm_units=20, learning_rate=0.001
# Training model with epochs=100, lstm_units=20, learning_rate=0.001
# Training model with epochs=100, lstm_units=20, learning_rate=0.001
# Training model with epochs=100, lstm_units=20, learning_rate=0.001
# Training model with epochs=100, lstm_units=20, learning_rate=0.001
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001
# Training model with epochs=100, lstm_units=20, learning_rate=0.0001
# Training model with epochs=100, lstm_units=50, learning_rate=0.01
# Training model with epochs=100, lstm_units=50, learning_rate=0.01
# Training model with epochs=100, lstm_units=50, learning_rate=0.01
# Training model with epochs=100, lstm_units=50, learning_rate=0.01
# Training model with epochs=100, lstm_units=50, learning_rate=0.01
# Training model with epochs=100, lstm_units=50, learning_rate=0.01
# Training model with epochs=100, lstm_units=50, learning_rate=0.01
# Training model with epochs=100, lstm_units=50, learning_rate=0.01
# Training model with epochs=100, lstm_units=50, learning_rate=0.01
# Training model with epochs=100, lstm_units=50, learning_rate=0.001
# Training model with epochs=100, lstm_units=50, learning_rate=0.001
# Training model with epochs=100, lstm_units=50, learning_rate=0.001
# Training model with epochs=100, lstm_units=50, learning_rate=0.001
# Training model with epochs=100, lstm_units=50, learning_rate=0.001
# Training model with epochs=100, lstm_units=50, learning_rate=0.001
# Training model with epochs=100, lstm_units=50, learning_rate=0.001
# Training model with epochs=100, lstm_units=50, learning_rate=0.001
# Training model with epochs=100, lstm_units=50, learning_rate=0.001
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001
# Training model with epochs=100, lstm_units=50, learning_rate=0.0001
# Training model with epochs=150, lstm_units=10, learning_rate=0.01
# Training model with epochs=150, lstm_units=10, learning_rate=0.01
# Training model with epochs=150, lstm_units=10, learning_rate=0.01
# Training model with epochs=150, lstm_units=10, learning_rate=0.01
# Training model with epochs=150, lstm_units=10, learning_rate=0.01
# Training model with epochs=150, lstm_units=10, learning_rate=0.01
# Training model with epochs=150, lstm_units=10, learning_rate=0.01
# Training model with epochs=150, lstm_units=10, learning_rate=0.01
# Training model with epochs=150, lstm_units=10, learning_rate=0.01
# Training model with epochs=150, lstm_units=10, learning_rate=0.001
# Training model with epochs=150, lstm_units=10, learning_rate=0.001
# Training model with epochs=150, lstm_units=10, learning_rate=0.001
# Training model with epochs=150, lstm_units=10, learning_rate=0.001
# Training model with epochs=150, lstm_units=10, learning_rate=0.001
# Training model with epochs=150, lstm_units=10, learning_rate=0.001
# Training model with epochs=150, lstm_units=10, learning_rate=0.001
# Training model with epochs=150, lstm_units=10, learning_rate=0.001
# Training model with epochs=150, lstm_units=10, learning_rate=0.001
# Training model with epochs=150, lstm_units=10, learning_rate=0.0001
# Training model with epochs=150, lstm_units=10, learning_rate=0.0001
# Training model with epochs=150, lstm_units=10, learning_rate=0.0001
# Training model with epochs=150, lstm_units=10, learning_rate=0.0001
# Training model with epochs=150, lstm_units=10, learning_rate=0.0001
# Training model with epochs=150, lstm_units=10, learning_rate=0.0001
# Training model with epochs=150, lstm_units=10, learning_rate=0.0001
# Training model with epochs=150, lstm_units=10, learning_rate=0.0001
# Training model with epochs=150, lstm_units=10, learning_rate=0.0001
# Training model with epochs=150, lstm_units=20, learning_rate=0.01
# Training model with epochs=150, lstm_units=20, learning_rate=0.01
# Training model with epochs=150, lstm_units=20, learning_rate=0.01
# Training model with epochs=150, lstm_units=20, learning_rate=0.01
# Training model with epochs=150, lstm_units=20, learning_rate=0.01
# Training model with epochs=150, lstm_units=20, learning_rate=0.01
# Training model with epochs=150, lstm_units=20, learning_rate=0.01
# Training model with epochs=150, lstm_units=20, learning_rate=0.01
# Training model with epochs=150, lstm_units=20, learning_rate=0.01
# Training model with epochs=150, lstm_units=20, learning_rate=0.001
# Training model with epochs=150, lstm_units=20, learning_rate=0.001
# Training model with epochs=150, lstm_units=20, learning_rate=0.001
# Training model with epochs=150, lstm_units=20, learning_rate=0.001
# Training model with epochs=150, lstm_units=20, learning_rate=0.001
# Training model with epochs=150, lstm_units=20, learning_rate=0.001
# Training model with epochs=150, lstm_units=20, learning_rate=0.001
# Training model with epochs=150, lstm_units=20, learning_rate=0.001
# Training model with epochs=150, lstm_units=20, learning_rate=0.001
# Training model with epochs=150, lstm_units=20, learning_rate=0.0001
# Training model with epochs=150, lstm_units=20, learning_rate=0.0001
# Training model with epochs=150, lstm_units=20, learning_rate=0.0001
# Training model with epochs=150, lstm_units=20, learning_rate=0.0001
# Training model with epochs=150, lstm_units=20, learning_rate=0.0001
# Training model with epochs=150, lstm_units=20, learning_rate=0.0001
# Training model with epochs=150, lstm_units=20, learning_rate=0.0001
# Training model with epochs=150, lstm_units=20, learning_rate=0.0001
# Training model with epochs=150, lstm_units=20, learning_rate=0.0001
# Training model with epochs=150, lstm_units=50, learning_rate=0.01
# Training model with epochs=150, lstm_units=50, learning_rate=0.01
# Training model with epochs=150, lstm_units=50, learning_rate=0.01
# Training model with epochs=150, lstm_units=50, learning_rate=0.01
# Training model with epochs=150, lstm_units=50, learning_rate=0.01
# Training model with epochs=150, lstm_units=50, learning_rate=0.01
# Training model with epochs=150, lstm_units=50, learning_rate=0.01
# Training model with epochs=150, lstm_units=50, learning_rate=0.01
# Training model with epochs=150, lstm_units=50, learning_rate=0.01
# Training model with epochs=150, lstm_units=50, learning_rate=0.001
# Training model with epochs=150, lstm_units=50, learning_rate=0.001
# Training model with epochs=150, lstm_units=50, learning_rate=0.001
# Training model with epochs=150, lstm_units=50, learning_rate=0.001
# Training model with epochs=150, lstm_units=50, learning_rate=0.001
# Training model with epochs=150, lstm_units=50, learning_rate=0.001
# Training model with epochs=150, lstm_units=50, learning_rate=0.001
# Training model with epochs=150, lstm_units=50, learning_rate=0.001
# Training model with epochs=150, lstm_units=50, learning_rate=0.001
# Training model with epochs=150, lstm_units=50, learning_rate=0.0001
# Training model with epochs=150, lstm_units=50, learning_rate=0.0001
# Training model with epochs=150, lstm_units=50, learning_rate=0.0001
# Training model with epochs=150, lstm_units=50, learning_rate=0.0001
# Training model with epochs=150, lstm_units=50, learning_rate=0.0001
# Training model with epochs=150, lstm_units=50, learning_rate=0.0001
# Training model with epochs=150, lstm_units=50, learning_rate=0.0001
# Training model with epochs=150, lstm_units=50, learning_rate=0.0001
# Training model with epochs=150, lstm_units=50, learning_rate=0.0001
# Best combination: epochs=150, lstm_units=50, learning_rate=0.001, Validation Loss=0.00012990056711714715, best_dense1=100, best_dense2=100

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers

model = Sequential([layers.Input((11, 1)),
                   layers.LSTM(50),
                   layers.Dense(100, activation='relu'),
                   layers.Dense(100, activation='relu'),
                   layers.Dense(1)])

model.compile(loss='mse',
              optimizer=Adam(learning_rate=0.001),
              metrics=['mean_absolute_error'])


history=model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs=150)

print(history.history.keys())

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')

# Add labels and legend
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/150
# 33/33 [==============================] - 4s 27ms/step - loss: 0.3034 - mean_absolute_error: 0.4093 - val_loss: 0.0060 - val_mean_absolute_error: 0.0589
# Epoch 2/150
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0099 - mean_absolute_error: 0.0788 - val_loss: 0.0038 - val_mean_absolute_error: 0.0518
# Epoch 3/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0056 - mean_absolute_error: 0.0607 - val_loss: 0.0024 - val_mean_absolute_error: 0.0376
# Epoch 4/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0050 - mean_absolute_error: 0.0577 - val_loss: 0.0031 - val_mean_absolute_error: 0.0472
# Epoch 5/150
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0050 - mean_absolute_error: 0.0577 - val_loss: 0.0032 - val_mean_absolute_error: 0.0483
# Epoch 6/150
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0043 - mean_absolute_error: 0.0543 - val_loss: 0.0052 - val_mean_absolute_error: 0.0645
# Epoch 7/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0045 - mean_absolute_error: 0.0549 - val_loss: 0.0024 - val_mean_absolute_error: 0.0415
# Epoch 8/150
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0042 - mean_absolute_error: 0.0536 - val_loss: 0.0021 - val_mean_absolute_error: 0.0378
# Epoch 9/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0038 - mean_absolute_error: 0.0518 - val_loss: 0.0016 - val_mean_absolute_error: 0.0323
# Epoch 10/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0040 - mean_absolute_error: 0.0522 - val_loss: 0.0032 - val_mean_absolute_error: 0.0494
# Epoch 11/150
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0038 - mean_absolute_error: 0.0509 - val_loss: 0.0012 - val_mean_absolute_error: 0.0279
# Epoch 12/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0040 - mean_absolute_error: 0.0523 - val_loss: 0.0047 - val_mean_absolute_error: 0.0621
# Epoch 13/150
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0040 - mean_absolute_error: 0.0524 - val_loss: 0.0024 - val_mean_absolute_error: 0.0429
# Epoch 14/150
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0038 - mean_absolute_error: 0.0511 - val_loss: 0.0031 - val_mean_absolute_error: 0.0492
# Epoch 15/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0037 - mean_absolute_error: 0.0500 - val_loss: 8.7511e-04 - val_mean_absolute_error: 0.0234
# Epoch 16/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0036 - mean_absolute_error: 0.0497 - val_loss: 0.0017 - val_mean_absolute_error: 0.0339
# Epoch 17/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0034 - mean_absolute_error: 0.0484 - val_loss: 0.0011 - val_mean_absolute_error: 0.0259
# Epoch 18/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0033 - mean_absolute_error: 0.0481 - val_loss: 8.5714e-04 - val_mean_absolute_error: 0.0231
# Epoch 19/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0030 - mean_absolute_error: 0.0457 - val_loss: 0.0035 - val_mean_absolute_error: 0.0530
# Epoch 20/150
# 33/33 [==============================] - 0s 8ms/step - loss: 0.0029 - mean_absolute_error: 0.0444 - val_loss: 0.0024 - val_mean_absolute_error: 0.0424
# Epoch 21/150
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0028 - mean_absolute_error: 0.0436 - val_loss: 9.6293e-04 - val_mean_absolute_error: 0.0250
# Epoch 22/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0024 - mean_absolute_error: 0.0406 - val_loss: 0.0040 - val_mean_absolute_error: 0.0585
# Epoch 23/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0022 - mean_absolute_error: 0.0387 - val_loss: 0.0039 - val_mean_absolute_error: 0.0578
# Epoch 24/150
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0023 - mean_absolute_error: 0.0390 - val_loss: 0.0026 - val_mean_absolute_error: 0.0476
# Epoch 25/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0024 - mean_absolute_error: 0.0404 - val_loss: 4.2360e-04 - val_mean_absolute_error: 0.0167
# Epoch 26/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0014 - mean_absolute_error: 0.0303 - val_loss: 4.5375e-04 - val_mean_absolute_error: 0.0171
# Epoch 27/150
# 33/33 [==============================] - 0s 11ms/step - loss: 0.0013 - mean_absolute_error: 0.0294 - val_loss: 0.0017 - val_mean_absolute_error: 0.0379
# Epoch 28/150
# 33/33 [==============================] - 0s 10ms/step - loss: 0.0014 - mean_absolute_error: 0.0304 - val_loss: 3.8387e-04 - val_mean_absolute_error: 0.0168
# Epoch 29/150
# 33/33 [==============================] - 0s 9ms/step - loss: 5.9683e-04 - mean_absolute_error: 0.0195 - val_loss: 6.9217e-04 - val_mean_absolute_error: 0.0232
# Epoch 30/150
# 33/33 [==============================] - 0s 11ms/step - loss: 6.9834e-04 - mean_absolute_error: 0.0214 - val_loss: 7.2007e-04 - val_mean_absolute_error: 0.0237
# Epoch 31/150
# 33/33 [==============================] - 0s 13ms/step - loss: 5.7795e-04 - mean_absolute_error: 0.0188 - val_loss: 8.1556e-04 - val_mean_absolute_error: 0.0265
# Epoch 32/150
# 33/33 [==============================] - 0s 14ms/step - loss: 4.0319e-04 - mean_absolute_error: 0.0159 - val_loss: 7.1424e-04 - val_mean_absolute_error: 0.0246
# Epoch 33/150
# 33/33 [==============================] - 0s 12ms/step - loss: 3.6296e-04 - mean_absolute_error: 0.0148 - val_loss: 1.4777e-04 - val_mean_absolute_error: 0.0100
# Epoch 34/150
# 33/33 [==============================] - 0s 14ms/step - loss: 2.5346e-04 - mean_absolute_error: 0.0122 - val_loss: 2.2906e-04 - val_mean_absolute_error: 0.0123
# Epoch 35/150
# 33/33 [==============================] - 0s 14ms/step - loss: 2.6085e-04 - mean_absolute_error: 0.0122 - val_loss: 2.5717e-04 - val_mean_absolute_error: 0.0133
# Epoch 36/150
# 33/33 [==============================] - 0s 14ms/step - loss: 3.0186e-04 - mean_absolute_error: 0.0138 - val_loss: 0.0014 - val_mean_absolute_error: 0.0361
# Epoch 37/150
# 33/33 [==============================] - 0s 14ms/step - loss: 5.2619e-04 - mean_absolute_error: 0.0182 - val_loss: 3.5371e-04 - val_mean_absolute_error: 0.0165
# Epoch 38/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2708e-04 - mean_absolute_error: 0.0113 - val_loss: 4.5956e-04 - val_mean_absolute_error: 0.0194
# Epoch 39/150
# 33/33 [==============================] - 0s 10ms/step - loss: 2.3192e-04 - mean_absolute_error: 0.0118 - val_loss: 8.9461e-05 - val_mean_absolute_error: 0.0076
# Epoch 40/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0664e-04 - mean_absolute_error: 0.0110 - val_loss: 1.7940e-04 - val_mean_absolute_error: 0.0111
# Epoch 41/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.6179e-04 - mean_absolute_error: 0.0126 - val_loss: 2.1153e-04 - val_mean_absolute_error: 0.0126
# Epoch 42/150
# 33/33 [==============================] - 0s 11ms/step - loss: 2.8862e-04 - mean_absolute_error: 0.0135 - val_loss: 0.0018 - val_mean_absolute_error: 0.0409
# Epoch 43/150
# 33/33 [==============================] - 0s 9ms/step - loss: 5.8930e-04 - mean_absolute_error: 0.0193 - val_loss: 3.4318e-04 - val_mean_absolute_error: 0.0156
# Epoch 44/150
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5770e-04 - mean_absolute_error: 0.0149 - val_loss: 1.9338e-04 - val_mean_absolute_error: 0.0116
# Epoch 45/150
# 33/33 [==============================] - 0s 10ms/step - loss: 2.7246e-04 - mean_absolute_error: 0.0132 - val_loss: 8.1988e-05 - val_mean_absolute_error: 0.0076
# Epoch 46/150
# 33/33 [==============================] - 0s 10ms/step - loss: 1.9263e-04 - mean_absolute_error: 0.0107 - val_loss: 3.5160e-04 - val_mean_absolute_error: 0.0170
# Epoch 47/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.6106e-04 - mean_absolute_error: 0.0126 - val_loss: 8.9942e-05 - val_mean_absolute_error: 0.0075
# Epoch 48/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.6991e-04 - mean_absolute_error: 0.0100 - val_loss: 5.9586e-04 - val_mean_absolute_error: 0.0229
# Epoch 49/150
# 33/33 [==============================] - 0s 10ms/step - loss: 3.0064e-04 - mean_absolute_error: 0.0143 - val_loss: 1.5972e-04 - val_mean_absolute_error: 0.0103
# Epoch 50/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0161e-04 - mean_absolute_error: 0.0107 - val_loss: 2.2732e-04 - val_mean_absolute_error: 0.0130
# Epoch 51/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2866e-04 - mean_absolute_error: 0.0116 - val_loss: 1.9750e-04 - val_mean_absolute_error: 0.0115
# Epoch 52/150
# 33/33 [==============================] - 0s 10ms/step - loss: 2.5239e-04 - mean_absolute_error: 0.0124 - val_loss: 3.3415e-04 - val_mean_absolute_error: 0.0164
# Epoch 53/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.9080e-04 - mean_absolute_error: 0.0105 - val_loss: 2.0300e-04 - val_mean_absolute_error: 0.0119
# Epoch 54/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0064e-04 - mean_absolute_error: 0.0109 - val_loss: 2.0645e-04 - val_mean_absolute_error: 0.0117
# Epoch 55/150
# 33/33 [==============================] - 0s 10ms/step - loss: 2.0461e-04 - mean_absolute_error: 0.0112 - val_loss: 8.6764e-05 - val_mean_absolute_error: 0.0078
# Epoch 56/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.7924e-04 - mean_absolute_error: 0.0104 - val_loss: 3.4055e-04 - val_mean_absolute_error: 0.0166
# Epoch 57/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.8453e-04 - mean_absolute_error: 0.0137 - val_loss: 7.5405e-04 - val_mean_absolute_error: 0.0259
# Epoch 58/150
# 33/33 [==============================] - 0s 10ms/step - loss: 7.7011e-04 - mean_absolute_error: 0.0222 - val_loss: 5.1026e-04 - val_mean_absolute_error: 0.0206
# Epoch 59/150
# 33/33 [==============================] - 0s 9ms/step - loss: 3.5278e-04 - mean_absolute_error: 0.0146 - val_loss: 4.6446e-04 - val_mean_absolute_error: 0.0199
# Epoch 60/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4223e-04 - mean_absolute_error: 0.0122 - val_loss: 2.6642e-04 - val_mean_absolute_error: 0.0142
# Epoch 61/150
# 33/33 [==============================] - 0s 10ms/step - loss: 1.5352e-04 - mean_absolute_error: 0.0094 - val_loss: 8.9412e-04 - val_mean_absolute_error: 0.0284
# Epoch 62/150
# 33/33 [==============================] - 0s 9ms/step - loss: 3.2561e-04 - mean_absolute_error: 0.0139 - val_loss: 0.0010 - val_mean_absolute_error: 0.0306
# Epoch 63/150
# 33/33 [==============================] - 0s 9ms/step - loss: 5.7735e-04 - mean_absolute_error: 0.0201 - val_loss: 9.2048e-05 - val_mean_absolute_error: 0.0079
# Epoch 64/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.7332e-04 - mean_absolute_error: 0.0123 - val_loss: 1.6557e-04 - val_mean_absolute_error: 0.0103
# Epoch 65/150
# 33/33 [==============================] - 0s 11ms/step - loss: 2.0414e-04 - mean_absolute_error: 0.0109 - val_loss: 1.8890e-04 - val_mean_absolute_error: 0.0115
# Epoch 66/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.8376e-04 - mean_absolute_error: 0.0104 - val_loss: 0.0010 - val_mean_absolute_error: 0.0310
# Epoch 67/150
# 33/33 [==============================] - 0s 9ms/step - loss: 3.8432e-04 - mean_absolute_error: 0.0164 - val_loss: 1.4049e-04 - val_mean_absolute_error: 0.0101
# Epoch 68/150
# 33/33 [==============================] - 0s 11ms/step - loss: 2.7499e-04 - mean_absolute_error: 0.0133 - val_loss: 8.4026e-05 - val_mean_absolute_error: 0.0072
# Epoch 69/150
# 33/33 [==============================] - 0s 11ms/step - loss: 2.1963e-04 - mean_absolute_error: 0.0114 - val_loss: 4.6619e-04 - val_mean_absolute_error: 0.0200
# Epoch 70/150
# 33/33 [==============================] - 0s 15ms/step - loss: 2.7471e-04 - mean_absolute_error: 0.0133 - val_loss: 1.5411e-04 - val_mean_absolute_error: 0.0099
# Epoch 71/150
# 33/33 [==============================] - 0s 12ms/step - loss: 1.7329e-04 - mean_absolute_error: 0.0101 - val_loss: 3.7962e-04 - val_mean_absolute_error: 0.0176
# Epoch 72/150
# 33/33 [==============================] - 0s 12ms/step - loss: 1.7178e-04 - mean_absolute_error: 0.0100 - val_loss: 0.0011 - val_mean_absolute_error: 0.0314
# Epoch 73/150
# 33/33 [==============================] - 0s 14ms/step - loss: 3.0370e-04 - mean_absolute_error: 0.0137 - val_loss: 1.3457e-04 - val_mean_absolute_error: 0.0093
# Epoch 74/150
# 33/33 [==============================] - 0s 14ms/step - loss: 1.9530e-04 - mean_absolute_error: 0.0107 - val_loss: 3.9249e-04 - val_mean_absolute_error: 0.0181
# Epoch 75/150
# 33/33 [==============================] - 0s 14ms/step - loss: 2.1742e-04 - mean_absolute_error: 0.0117 - val_loss: 1.0338e-04 - val_mean_absolute_error: 0.0080
# Epoch 76/150
# 33/33 [==============================] - 0s 13ms/step - loss: 1.6006e-04 - mean_absolute_error: 0.0097 - val_loss: 8.2459e-05 - val_mean_absolute_error: 0.0072
# Epoch 77/150
# 33/33 [==============================] - 0s 12ms/step - loss: 1.4789e-04 - mean_absolute_error: 0.0091 - val_loss: 6.4450e-05 - val_mean_absolute_error: 0.0064
# Epoch 78/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.3824e-04 - mean_absolute_error: 0.0088 - val_loss: 2.2014e-04 - val_mean_absolute_error: 0.0129
# Epoch 79/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.8956e-04 - mean_absolute_error: 0.0106 - val_loss: 8.8562e-04 - val_mean_absolute_error: 0.0287
# Epoch 80/150
# 33/33 [==============================] - 0s 10ms/step - loss: 3.2284e-04 - mean_absolute_error: 0.0147 - val_loss: 4.6100e-04 - val_mean_absolute_error: 0.0196
# Epoch 81/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.9767e-04 - mean_absolute_error: 0.0137 - val_loss: 0.0015 - val_mean_absolute_error: 0.0379
# Epoch 82/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.8558e-04 - mean_absolute_error: 0.0127 - val_loss: 2.4013e-04 - val_mean_absolute_error: 0.0136
# Epoch 83/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.5343e-04 - mean_absolute_error: 0.0094 - val_loss: 7.1207e-04 - val_mean_absolute_error: 0.0254
# Epoch 84/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2022e-04 - mean_absolute_error: 0.0115 - val_loss: 3.6076e-04 - val_mean_absolute_error: 0.0170
# Epoch 85/150
# 33/33 [==============================] - 0s 8ms/step - loss: 2.1263e-04 - mean_absolute_error: 0.0115 - val_loss: 7.3929e-05 - val_mean_absolute_error: 0.0069
# Epoch 86/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.3325e-04 - mean_absolute_error: 0.0087 - val_loss: 8.2117e-05 - val_mean_absolute_error: 0.0071
# Epoch 87/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.2943e-04 - mean_absolute_error: 0.0086 - val_loss: 6.8322e-04 - val_mean_absolute_error: 0.0247
# Epoch 88/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.4137e-04 - mean_absolute_error: 0.0122 - val_loss: 6.0667e-05 - val_mean_absolute_error: 0.0062
# Epoch 89/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.9544e-04 - mean_absolute_error: 0.0108 - val_loss: 3.8724e-04 - val_mean_absolute_error: 0.0180
# Epoch 90/150
# 33/33 [==============================] - 0s 10ms/step - loss: 2.1098e-04 - mean_absolute_error: 0.0115 - val_loss: 1.6617e-04 - val_mean_absolute_error: 0.0107
# Epoch 91/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0168e-04 - mean_absolute_error: 0.0110 - val_loss: 6.8747e-05 - val_mean_absolute_error: 0.0065
# Epoch 92/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1264e-04 - mean_absolute_error: 0.0114 - val_loss: 6.7417e-04 - val_mean_absolute_error: 0.0248
# Epoch 93/150
# 33/33 [==============================] - 0s 10ms/step - loss: 2.5487e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0010 - val_mean_absolute_error: 0.0306
# Epoch 94/150
# 33/33 [==============================] - 0s 9ms/step - loss: 3.0236e-04 - mean_absolute_error: 0.0137 - val_loss: 9.2030e-05 - val_mean_absolute_error: 0.0081
# Epoch 95/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.5925e-04 - mean_absolute_error: 0.0098 - val_loss: 9.3544e-05 - val_mean_absolute_error: 0.0076
# Epoch 96/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.5732e-04 - mean_absolute_error: 0.0097 - val_loss: 1.9227e-04 - val_mean_absolute_error: 0.0120
# Epoch 97/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.9176e-04 - mean_absolute_error: 0.0108 - val_loss: 2.2635e-04 - val_mean_absolute_error: 0.0132
# Epoch 98/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0036e-04 - mean_absolute_error: 0.0111 - val_loss: 1.5103e-04 - val_mean_absolute_error: 0.0102
# Epoch 99/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.4482e-04 - mean_absolute_error: 0.0092 - val_loss: 8.2659e-05 - val_mean_absolute_error: 0.0076
# Epoch 100/150
# 33/33 [==============================] - 0s 10ms/step - loss: 1.3110e-04 - mean_absolute_error: 0.0086 - val_loss: 5.0497e-04 - val_mean_absolute_error: 0.0208
# Epoch 101/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.9723e-04 - mean_absolute_error: 0.0141 - val_loss: 1.8931e-04 - val_mean_absolute_error: 0.0116
# Epoch 102/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1919e-04 - mean_absolute_error: 0.0114 - val_loss: 1.7307e-04 - val_mean_absolute_error: 0.0112
# Epoch 103/150
# 33/33 [==============================] - 0s 10ms/step - loss: 1.7078e-04 - mean_absolute_error: 0.0103 - val_loss: 1.2695e-04 - val_mean_absolute_error: 0.0093
# Epoch 104/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5883e-04 - mean_absolute_error: 0.0127 - val_loss: 3.8176e-04 - val_mean_absolute_error: 0.0174
# Epoch 105/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.5964e-04 - mean_absolute_error: 0.0124 - val_loss: 8.0510e-05 - val_mean_absolute_error: 0.0071
# Epoch 106/150
# 33/33 [==============================] - 0s 10ms/step - loss: 1.4884e-04 - mean_absolute_error: 0.0093 - val_loss: 1.4630e-04 - val_mean_absolute_error: 0.0099
# Epoch 107/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2174e-04 - mean_absolute_error: 0.0114 - val_loss: 7.0370e-05 - val_mean_absolute_error: 0.0067
# Epoch 108/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.2732e-04 - mean_absolute_error: 0.0118 - val_loss: 0.0010 - val_mean_absolute_error: 0.0297
# Epoch 109/150
# 33/33 [==============================] - 0s 10ms/step - loss: 4.3170e-04 - mean_absolute_error: 0.0167 - val_loss: 1.0890e-04 - val_mean_absolute_error: 0.0086
# Epoch 110/150
# 33/33 [==============================] - 1s 15ms/step - loss: 1.7679e-04 - mean_absolute_error: 0.0101 - val_loss: 8.5668e-05 - val_mean_absolute_error: 0.0075
# Epoch 111/150
# 33/33 [==============================] - 0s 14ms/step - loss: 2.6233e-04 - mean_absolute_error: 0.0128 - val_loss: 0.0023 - val_mean_absolute_error: 0.0461
# Epoch 112/150
# 33/33 [==============================] - 0s 12ms/step - loss: 6.6091e-04 - mean_absolute_error: 0.0218 - val_loss: 0.0012 - val_mean_absolute_error: 0.0329
# Epoch 113/150
# 33/33 [==============================] - 0s 15ms/step - loss: 2.6704e-04 - mean_absolute_error: 0.0126 - val_loss: 0.0011 - val_mean_absolute_error: 0.0318
# Epoch 114/150
# 33/33 [==============================] - 0s 14ms/step - loss: 3.7411e-04 - mean_absolute_error: 0.0155 - val_loss: 3.3135e-04 - val_mean_absolute_error: 0.0164
# Epoch 115/150
# 33/33 [==============================] - 0s 14ms/step - loss: 1.7454e-04 - mean_absolute_error: 0.0100 - val_loss: 1.4685e-04 - val_mean_absolute_error: 0.0097
# Epoch 116/150
# 33/33 [==============================] - 0s 14ms/step - loss: 1.5792e-04 - mean_absolute_error: 0.0096 - val_loss: 8.5259e-05 - val_mean_absolute_error: 0.0073
# Epoch 117/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.5604e-04 - mean_absolute_error: 0.0096 - val_loss: 2.0475e-04 - val_mean_absolute_error: 0.0124
# Epoch 118/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.8921e-04 - mean_absolute_error: 0.0107 - val_loss: 0.0012 - val_mean_absolute_error: 0.0331
# Epoch 119/150
# 33/33 [==============================] - 0s 9ms/step - loss: 8.9313e-04 - mean_absolute_error: 0.0240 - val_loss: 1.3353e-04 - val_mean_absolute_error: 0.0096
# Epoch 120/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.7799e-04 - mean_absolute_error: 0.0100 - val_loss: 3.7334e-04 - val_mean_absolute_error: 0.0174
# Epoch 121/150
# 33/33 [==============================] - 0s 10ms/step - loss: 1.5819e-04 - mean_absolute_error: 0.0095 - val_loss: 3.1848e-04 - val_mean_absolute_error: 0.0158
# Epoch 122/150
# 33/33 [==============================] - 0s 9ms/step - loss: 3.0925e-04 - mean_absolute_error: 0.0140 - val_loss: 1.4509e-04 - val_mean_absolute_error: 0.0096
# Epoch 123/150
# 33/33 [==============================] - 0s 8ms/step - loss: 1.4862e-04 - mean_absolute_error: 0.0092 - val_loss: 1.6831e-04 - val_mean_absolute_error: 0.0106
# Epoch 124/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.5092e-04 - mean_absolute_error: 0.0095 - val_loss: 1.8429e-04 - val_mean_absolute_error: 0.0113
# Epoch 125/150
# 33/33 [==============================] - 0s 10ms/step - loss: 1.3925e-04 - mean_absolute_error: 0.0089 - val_loss: 7.3801e-05 - val_mean_absolute_error: 0.0069
# Epoch 126/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.7863e-04 - mean_absolute_error: 0.0102 - val_loss: 0.0024 - val_mean_absolute_error: 0.0482
# Epoch 127/150
# 33/33 [==============================] - 0s 10ms/step - loss: 6.3183e-04 - mean_absolute_error: 0.0194 - val_loss: 2.2477e-04 - val_mean_absolute_error: 0.0127
# Epoch 128/150
# 33/33 [==============================] - 0s 10ms/step - loss: 2.3535e-04 - mean_absolute_error: 0.0122 - val_loss: 4.0385e-04 - val_mean_absolute_error: 0.0181
# Epoch 129/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.8213e-04 - mean_absolute_error: 0.0104 - val_loss: 1.4386e-04 - val_mean_absolute_error: 0.0098
# Epoch 130/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.3075e-04 - mean_absolute_error: 0.0121 - val_loss: 1.1910e-04 - val_mean_absolute_error: 0.0090
# Epoch 131/150
# 33/33 [==============================] - 0s 11ms/step - loss: 1.8101e-04 - mean_absolute_error: 0.0104 - val_loss: 1.0366e-04 - val_mean_absolute_error: 0.0082
# Epoch 132/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.7847e-04 - mean_absolute_error: 0.0105 - val_loss: 3.9430e-04 - val_mean_absolute_error: 0.0182
# Epoch 133/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.0724e-04 - mean_absolute_error: 0.0112 - val_loss: 9.9844e-05 - val_mean_absolute_error: 0.0081
# Epoch 134/150
# 33/33 [==============================] - 0s 11ms/step - loss: 1.3241e-04 - mean_absolute_error: 0.0086 - val_loss: 1.8373e-04 - val_mean_absolute_error: 0.0112
# Epoch 135/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.9193e-04 - mean_absolute_error: 0.0110 - val_loss: 4.0277e-04 - val_mean_absolute_error: 0.0145
# Epoch 136/150
# 33/33 [==============================] - 0s 9ms/step - loss: 0.0017 - mean_absolute_error: 0.0327 - val_loss: 7.2927e-04 - val_mean_absolute_error: 0.0238
# Epoch 137/150
# 33/33 [==============================] - 0s 11ms/step - loss: 2.9539e-04 - mean_absolute_error: 0.0128 - val_loss: 1.0599e-04 - val_mean_absolute_error: 0.0087
# Epoch 138/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.5816e-04 - mean_absolute_error: 0.0094 - val_loss: 3.5594e-04 - val_mean_absolute_error: 0.0169
# Epoch 139/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.6132e-04 - mean_absolute_error: 0.0131 - val_loss: 9.3875e-04 - val_mean_absolute_error: 0.0293
# Epoch 140/150
# 33/33 [==============================] - 0s 10ms/step - loss: 4.0806e-04 - mean_absolute_error: 0.0163 - val_loss: 1.7801e-04 - val_mean_absolute_error: 0.0111
# Epoch 141/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.6450e-04 - mean_absolute_error: 0.0127 - val_loss: 0.0010 - val_mean_absolute_error: 0.0305
# Epoch 142/150
# 33/33 [==============================] - 0s 9ms/step - loss: 4.8439e-04 - mean_absolute_error: 0.0180 - val_loss: 2.8460e-04 - val_mean_absolute_error: 0.0148
# Epoch 143/150
# 33/33 [==============================] - 0s 9ms/step - loss: 2.1557e-04 - mean_absolute_error: 0.0115 - val_loss: 2.2248e-04 - val_mean_absolute_error: 0.0130
# Epoch 144/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.5425e-04 - mean_absolute_error: 0.0095 - val_loss: 2.4254e-04 - val_mean_absolute_error: 0.0135
# Epoch 145/150
# 33/33 [==============================] - 0s 9ms/step - loss: 1.6580e-04 - mean_absolute_error: 0.0099 - val_loss: 2.4971e-04 - val_mean_absolute_error: 0.0137
# Epoch 146/150
# 33/33 [==============================] - 0s 8ms/step - loss: 1.5140e-04 - mean_absolute_error: 0.0094 - val_loss: 6.4887e-05 - val_mean_absolute_error: 0.0066
# Epoch 147/150
# 33/33 [==============================] - 0s 10ms/step - loss: 1.5793e-04 - mean_absolute_error: 0.0095 - val_loss: 6.1658e-04 - val_mean_absolute_error: 0.0233
# Epoch 148/150
# 33/33 [==============================] - 0s 10ms/step - loss: 2.0718e-04 - mean_absolute_error: 0.0111 - val_loss: 5.6015e-04 - val_mean_absolute_error: 0.0221
# Epoch 149/150
# 33/33 [==============================] - 0s 13ms/step - loss: 1.9685e-04 - mean_absolute_error: 0.0108 - val_loss: 2.6745e-04 - val_mean_absolute_error: 0.0138
# Epoch 150/150
# 33/33 [==============================] - 0s 13ms/step - loss: 2.0557e-04 - mean_absolute_error: 0.0111 - val_loss: 9.6079e-05 - val_mean_absolute_error: 0.0077
# dict_keys(['loss', 'mean_absolute_error', 'val_loss', 'val_mean_absolute_error'])

# %%
from sklearn.metrics import mean_squared_error

train_predictions = model.predict(X_train).flatten()
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.legend(['Training Predictions', 'Training Observations'])
# Out:
# 33/33 [==============================] - 1s 3ms/step

# %%
import numpy as np

basis_point_value=0.01  #For USDLKR pair
train_data_basis_point_diff=((train_predictions/basis_point_value).flatten()-y_train/basis_point_value).abs()
plt.plot(dates_train, train_data_basis_point_diff)

average_train_data_basis_point_diff=np.mean(train_data_basis_point_diff)
print(average_train_data_basis_point_diff)
# Out:
# 0.8807667504644612

# %%
val_predictions = model.predict(X_val).flatten()
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.legend(['Validation Predictions', 'Validation Observations'])
# Out:
# 4/4 [==============================] - 0s 6ms/step

# %%
basis_point_value=0.01  #For USDLKR pair
validation_data_basis_point_diff=((val_predictions/basis_point_value).flatten()-y_val/basis_point_value).abs()
plt.plot(dates_val, validation_data_basis_point_diff)

print(np.mean(validation_data_basis_point_diff))
# Out:
# 0.7658336061477642

# %%
test_predictions = model.predict(X_test).flatten()

plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Testing Predictions', 'Testing Observations'])
# Out:
# 5/5 [==============================] - 0s 6ms/step

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# Assuming test_predictions and y_test are lists or numpy arrays
# Calculate MSE and MAE
mse = mean_squared_error(y_test, test_predictions)
print("Mean Square Error:", mse)
mae=mean_absolute_error(y_test, test_predictions)
print("Mean Absolute Error:", mae)
# Out:
# Mean Square Error: 5.861547527275051e-05
# Mean Absolute Error: 0.006393816059142111

# %%
basis_point_value=0.01  #For USDLKR pair
test_data_basis_point_diff=((test_predictions/basis_point_value).flatten()-y_test/basis_point_value).abs()
plt.plot(dates_test, test_data_basis_point_diff)

print(np.mean(test_data_basis_point_diff))
# Out:
# 0.6393797022619896

# %%
#Start Trading with 1000 LKR with model


number_of_trading_days=dates_test.size
test_data=y_test.values
holding_currency="quote"
holding_value=1000
for current_trading_day in range(number_of_trading_days-1):
  if holding_currency=="quote":
    if (test_predictions[current_trading_day+1]>test_data[current_trading_day]):
      holding_value=holding_value/test_data[current_trading_day]
      holding_currency="base"
  else:
    if (test_predictions[current_trading_day+1]<test_data[current_trading_day]):
      holding_value=test_data[current_trading_day]*holding_value
      holding_currency="quote"


if holding_currency=="base":
  holding_value=test_data[current_trading_day]*holding_value

print(number_of_trading_days)
print(holding_value)
print(holding_currency)
# Out:
# 129
# 1011.7536685129951
# quote

# %%
#Start Trading with 1000 USD LKR actual values


number_of_trading_days=dates_test.size
test_data=y_test.values
holding_currency="quote"
holding_value=1000
for current_trading_day in range(number_of_trading_days-1):
  if holding_currency=="quote":
    if (test_data[current_trading_day+1]>test_data[current_trading_day]):
      holding_value=holding_value/test_data[current_trading_day]
      holding_currency="base"
  else:
    if (test_data[current_trading_day+1]<test_data[current_trading_day]):
      holding_value=test_data[current_trading_day]*holding_value
      holding_currency="quote"


if holding_currency=="base":
  holding_value=test_data[current_trading_day]*holding_value

print(number_of_trading_days)
print(holding_value)
print(holding_currency)
# Out:
# 129
# 1185.5255377520195
# quote

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations'])

# %%
from copy import deepcopy

recursive_predictions = []
recursive_dates = np.concatenate([dates_val, dates_test])

for target_date in recursive_dates:
  last_window = deepcopy(X_train[-1])
  next_prediction = model.predict(np.array([last_window])).flatten()
  recursive_predictions.append(next_prediction)
  last_window[-1] = next_prediction

# %%
plt.plot(dates_train, train_predictions)
plt.plot(dates_train, y_train)
plt.plot(dates_val, val_predictions)
plt.plot(dates_val, y_val)
plt.plot(dates_test, test_predictions)
plt.plot(dates_test, y_test)
plt.plot(recursive_dates, recursive_predictions)
plt.legend(['Training Predictions',
            'Training Observations',
            'Validation Predictions',
            'Validation Observations',
            'Testing Predictions',
            'Testing Observations',
            'Recursive Predictions'])
